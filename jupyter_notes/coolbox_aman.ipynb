# %%
#clr_1 = cooler.Cooler(f"/usr/users/papantonis1/aman/microc_data/nadine_macro/RBP1-MNase-R1-filtered.mcool::resolutions/{resolution}")
#clr_2 = cooler.Cooler(f"/usr/users/papantonis1/aman/microc_data/nadine_macro/ctrl-MNase-R1-filtered.mcool::resolutions/{resolution}")

#/usr/users/papantonis1/aman/microc_data/nadine_macro/RBP1-MNase-R1-filtered.mcool
#/usr/users/papantonis1/aman/microc_data/nadine_macro/ctrl-MNase-R1-filtered.mcool

# %%
import cooler
resolution = 10000
clr_1 = cooler.Cooler(f"/usr/users/papantonis1/aman/microc_data/nadine_macro/RBP1-MNase-R1-filtered.mcool::resolutions/{resolution}")

# %%
# change working directory
import os
os.chdir("/usr/users/papantonis1")
print(f"Current working directory: {os.path.abspath(os.curdir)}")
# Out:
# Current working directory: /home/uni08/papantonis1

# %%
import coolbox
from coolbox.api import *

# %%
coolbox.__version__
# Out:
# '0.3.9'

# %%
#dynamic length setting
chr_length = clr_1.chromsizes['chrY']

# %%
#cool_file = "./aman/microc_data/nadine_macro/RBP1-MNase-R1-filtered.mcool"
#test_range = "chr2:242193529-198295559"

# %%
import numpy; print(numpy.__version__)
# Out:
# 1.24.3

# %%
frame = XAxis() + HiCMat(cool_file, style='matrix', color_bar='horizontal')

# Plot full chr2
frame.plot(f"chr2:0-{chr_length}")

# %% [markdown]
# # Plot loops on to heatmaps
