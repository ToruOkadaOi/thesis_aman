# %%
library(CALDER)
# Out:
# Error in library(CALDER): there is no package called ‘CALDER’
# Traceback:
#
# 1. library(CALDER)

# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("GenomicRanges")
install.packages("remotes")
remotes::install_github("CSOgroup/CALDER2.0")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.25), R 4.3.3 (2024-02-29)
#
# Installing package(s) 'BiocVersion', 'GenomicRanges'
#
# also installing the dependencies ‘bitops’, ‘RCurl’, ‘GenomeInfoDbData’, ‘zlibbioc’, ‘BiocGenerics’, ‘S4Vectors’, ‘IRanges’, ‘GenomeInfoDb’, ‘XVector’
#
#
# Old packages: 'askpass', 'bit', 'bit64', 'boot', 'broom', 'bslib', 'caret',
#   'class', 'cli', 'clock', 'cluster', 'colorspace', 'commonmark', 'cpp11',
#   'crayon', 'crul', 'curl', 'data.table', 'digest', 'e1071', 'evaluate',
#   'fontawesome', 'foreign', 'fs', 'future', 'future.apply', 'generics',
#   'ggplot2', 'globals', 'glue', 'gower', 'gtable', 'hardhat', 'hexbin',
#   'httpuv', 'ipred', 'jsonlite', 'KernSmooth', 'knitr', 'later', 'lattice',
#   'lava', 'lubridate', 'maps', 'mgcv', 'mime', 'nlme', 'nnet', 'openssl',
#   'parallelly', 'pbdZMQ', 'pillar', 'processx', 'prodlim', 'progressr',
#   'promises', 'ps', 'purrr', 'quantmod', 'R6', 'ragg', 'randomForest', 'Rcpp',
#   'RcppEigen', 'readxl', 'recipes', 'reprex', 'rlang', 'rmarkdown', 'rpart',
#   'rstudioapi', 'sass', 'scales', 'shiny', 'spatial', 'stringi', 'survival',
#   'sys', 'systemfonts', 'textshaping', 'timeDate', 'tinytex', 'tzdb', 'utf8',
#   'uuid', 'withr', 'xfun', 'xml2', 'xts', 'yaml', 'zoo'
#
# Downloading GitHub repo CSOgroup/CALDER2.0@HEAD
# rlang        (1.1.4     -> 1.1.6    ) [CRAN]
# glue         (1.7.0     -> 1.8.0    ) [CRAN]
# cli          (3.6.2     -> 3.6.5    ) [CRAN]
# utf8         (1.2.4     -> 1.2.5    ) [CRAN]
# pillar       (1.9.0     -> 1.10.2   ) [CRAN]
# R6           (2.5.1     -> 2.6.1    ) [CRAN]
# Rhdf5lib     (NA        -> 1.22.1   ) [CRAN]
# Rcpp         (1.0.12    -> 1.0.14   ) [CRAN]
# dotCall64    (NA        -> 1.2      ) [CRAN]
# withr        (3.0.0     -> 3.0.2    ) [CRAN]
# stringi      (1.8.4     -> 1.8.7    ) [CRAN]
# generics     (0.1.3     -> 0.1.4    ) [CRAN]
# cpp11        (0.4.7     -> 0.5.2    ) [CRAN]
# purrr        (1.0.2     -> 1.0.4    ) [CRAN]
# gtable       (0.3.5     -> 0.3.6    ) [CRAN]
# scales       (1.3.0     -> 1.4.0    ) [CRAN]
# ggplot2      (3.5.1     -> 3.5.2    ) [CRAN]
# rbibutils    (NA        -> 2.3      ) [CRAN]
# Rdpack       (NA        -> 2.6.4    ) [CRAN]
# microbenc... (NA        -> 1.5.0    ) [CRAN]
# Deriv        (NA        -> 4.1.6    ) [CRAN]
# MatrixModels (NA        -> 0.5-4    ) [CRAN]
# SparseM      (NA        -> 1.84-2   ) [CRAN]
# doBy         (NA        -> 4.6.26   ) [CRAN]
# RcppEigen    (0.3.4.0.0 -> 0.3.4.0.2) [CRAN]
# reformulas   (NA        -> 0.4.1    ) [CRAN]
# nloptr       (NA        -> 2.2.1    ) [CRAN]
# minqa        (NA        -> 1.2.8    ) [CRAN]
# lme4         (NA        -> 1.1-37   ) [CRAN]
# quantreg     (NA        -> 6.1      ) [CRAN]
# pbkrtest     (NA        -> 0.5.4    ) [CRAN]
# Formula      (NA        -> 1.2-5    ) [CRAN]
# abind        (NA        -> 1.4-8    ) [CRAN]
# carData      (NA        -> 3.0-5    ) [CRAN]
# car          (NA        -> 3.1-3    ) [CRAN]
# corrplot     (NA        -> 0.95     ) [CRAN]
# broom        (1.0.6     -> 1.0.8    ) [CRAN]
# rstatix      (NA        -> 0.7.2    ) [CRAN]
# polynom      (NA        -> 1.4-1    ) [CRAN]
# gridExtra    (NA        -> 2.3      ) [CRAN]
# ggsignif     (NA        -> 0.6.4    ) [CRAN]
# cowplot      (NA        -> 1.1.3    ) [CRAN]
# ggsci        (NA        -> 3.2.0    ) [CRAN]
# ggrepel      (NA        -> 0.9.6    ) [CRAN]
# fs           (1.6.4     -> 1.6.6    ) [CRAN]
# sass         (0.4.9     -> 0.4.10   ) [CRAN]
# mime         (0.12      -> 0.13     ) [CRAN]
# tinytex      (0.51      -> 0.57     ) [CRAN]
# fontawesome  (0.5.2     -> 0.5.3    ) [CRAN]
# bslib        (0.7.0     -> 0.9.0    ) [CRAN]
# xfun         (0.45      -> 0.52     ) [CRAN]
# evaluate     (0.24.0    -> 1.0.3    ) [CRAN]
# later        (1.3.2     -> 1.4.2    ) [CRAN]
# yaml         (2.3.8     -> 2.3.10   ) [CRAN]
# rmarkdown    (2.27      -> 2.29     ) [CRAN]
# knitr        (1.47      -> 1.50     ) [CRAN]
# digest       (0.6.35    -> 0.6.37   ) [CRAN]
# mvtnorm      (NA        -> 1.3-3    ) [CRAN]
# estimability (NA        -> 1.5.1    ) [CRAN]
# promises     (1.3.0     -> 1.3.2    ) [CRAN]
# crosstalk    (NA        -> 1.2.1    ) [CRAN]
# jsonlite     (1.8.8     -> 2.0.0    ) [CRAN]
# httpuv       (1.6.15    -> 1.6.16   ) [CRAN]
# scatterpl... (NA        -> 0.3-44   ) [CRAN]
# multcompView (NA        -> 0.1-10   ) [CRAN]
# leaps        (NA        -> 3.2      ) [CRAN]
# flashClust   (NA        -> 1.01-2   ) [CRAN]
# emmeans      (NA        -> 1.11.1   ) [CRAN]
# ellipse      (NA        -> 0.5.0    ) [CRAN]
# DT           (NA        -> 0.33     ) [CRAN]
# viridis      (NA        -> 0.6.5    ) [CRAN]
# R.methodsS3  (NA        -> 1.8.2    ) [CRAN]
# getopt       (NA        -> 1.20.4   ) [CRAN]
# rhdf5filters (NA        -> 1.12.1   ) [CRAN]
# maps         (3.4.2     -> 3.4.2.1  ) [CRAN]
# spam         (NA        -> 2.11-1   ) [CRAN]
# ggpubr       (NA        -> 0.6.0    ) [CRAN]
# FactoMineR   (NA        -> 2.11     ) [CRAN]
# dendextend   (NA        -> 1.19.0   ) [CRAN]
# RSpectra     (NA        -> 0.16-2   ) [CRAN]
# R.oo         (NA        -> 1.27.1   ) [CRAN]
# RcppArmad... (NA        -> 14.4.2-1 ) [CRAN]
# optparse     (NA        -> 1.7.5    ) [CRAN]
# rhdf5        (NA        -> 2.44.0   ) [CRAN]
# strawr       (NA        -> 0.0.92   ) [CRAN]
# fields       (NA        -> 16.3.1   ) [CRAN]
# data.table   (1.15.4    -> 1.17.0   ) [CRAN]
# factoextra   (NA        -> 1.0.7    ) [CRAN]
# rARPACK      (NA        -> 0.11-0   ) [CRAN]
# igraph       (NA        -> 2.1.4    ) [CRAN]
# fitdistrplus (NA        -> 1.2-2    ) [CRAN]
# ape          (NA        -> 5.8-1    ) [CRAN]
# doParallel   (NA        -> 1.0.17   ) [CRAN]
# R.utils      (NA        -> 2.13.0   ) [CRAN]
# Skipping 1 packages not available: MASS
#
# Skipping 8 packages ahead of CRAN: zlibbioc, IRanges, S4Vectors, BiocGenerics, GenomeInfoDbData, XVector, GenomeInfoDb, GenomicRanges
#
# Installing 94 packages: rlang, glue, cli, utf8, pillar, R6, Rhdf5lib, Rcpp, dotCall64, withr, stringi, generics, cpp11, purrr, gtable, scales, ggplot2, rbibutils, Rdpack, microbenchmark, Deriv, MatrixModels, SparseM, doBy, RcppEigen, reformulas, nloptr, minqa, lme4, quantreg, pbkrtest, Formula, abind, carData, car, corrplot, broom, rstatix, polynom, gridExtra, ggsignif, cowplot, ggsci, ggrepel, fs, sass, mime, tinytex, fontawesome, bslib, xfun, evaluate, later, yaml, rmarkdown, knitr, digest, mvtnorm, estimability, promises, crosstalk, jsonlite, httpuv, scatterplot3d, multcompView, leaps, flashClust, emmeans, ellipse, DT, viridis, R.methodsS3, getopt, rhdf5filters, maps, spam, ggpubr, FactoMineR, dendextend, RSpectra, R.oo, RcppArmadillo, optparse, rhdf5, strawr, fields, data.table, factoextra, rARPACK, igraph, fitdistrplus, ape, doParallel, R.utils
#
# Warning message in i.p(...):
# “installation of package ‘nloptr’ had non-zero exit status”
