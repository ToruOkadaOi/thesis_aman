# %%
import numpy as np
matrix = np.load("/usr/users/papantonis1/diffana_chr1_selfish_10kb_output.npy")

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.DataFrame(matrix)
df
# Out:
#              0
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8         True
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17        True
# 18        True
# 19       False
# 20       False
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# ...        ...
# 2825766  False
# 2825767  False
# 2825768  False
# 2825769  False
# 2825770  False
# 2825771  False
# 2825772  False
# 2825773  False
# 2825774  False
# 2825775  False
# 2825776  False
# 2825777  False
# 2825778  False
# 2825779  False
# 2825780  False
# 2825781  False
# 2825782  False
# 2825783  False
# 2825784  False
# 2825785  False
# 2825786  False
# 2825787  False
# 2825788  False
# 2825789  False
# 2825790  False
# 2825791  False
# ...

# %%
import numpy as np

# Indices of True values
significant_bins = np.where(matrix)[0]

print(significant_bins[:10])  # first 10 True positions
# Out:
# [  3   8  17  18  21  22  23 102 225 263]
