# %%
import pandas as pd
genes=pd.read_csv("/usr/users/papantonis1/aman/rnaseq_data/upregulated_transcript_level_genebodies.bed",sep="\t", header=None, usecols=[1, 2])
genes
# Out:
#               1          2
# 0      11934204   11958620
# 1      11934693   11952691
# 2      11934716   11975537
# 3      11934733   11954767
# 4      11934742   11957943
# ...         ...        ...
# 2141  112780354  112822584
# 2142  112823136  112840683
# 2143  136665546  136767343
# 2144  136665546  136768627
# 2145  136665549  136780932
#
# [2146 rows x 2 columns]

# %%
gb_interval = genes.loc[:, 2] - genes.loc[:, 1]
gb_interval.describe()
# Out:
# count      2146.000000
# mean      53543.006524
# std      100442.784004
# min         289.000000
# 25%        6377.000000
# 50%       18719.500000
# 75%       54654.250000
# max      566169.000000
# dtype: float64
