# %%
import subprocess

def run_coolpuppy(
    mcool_path,
    bedpe_file,
    output_file,
    mindist=None,
    maxdist=None,
    seed=None,
    threads=1
):
    """
    Run coolpup.py using the 'cool_notebook' conda environment via subprocess.
    """
    coolpup_script = "/usr/users/papantonis1/anaconda3/envs/cool_notebook/bin/coolpup.py"

    # Build optional arguments
    opts = []
    if mindist is not None:
        opts += [f"--mindist {mindist}"]
    if maxdist is not None:
        opts += [f"--maxdist {maxdist}"]
    if seed is not None:
        opts += [f"--seed {seed}"]
    if threads > 1:
        opts += [f"-p {threads}"]

    # Compose full command
    cmd = [
        "bash", "-c",
        f"source ~/anaconda3/etc/profile.d/conda.sh && conda activate cool_notebook && "
        f"python {coolpup_script} --format bedpe {mcool_path} {bedpe_file} "
        f"{' '.join(opts)} -o {output_file}"
    ]

    subprocess.run(cmd, check=True)

# %%
mcool_path = "/usr/users/papantonis1/aman/microc_data/nadine_macro/ctrl-MNase-R1-filtered.mcool::resolutions/10000"

# %%
run_coolpuppy(
    mcool_path,
    "/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/merged_loops_3tools/unique_cooldots_ctrl_fixed.bedpe",
    "unique_cooldots_ctrl_fixed.npz",
    threads=8
)
# Out:
# /usr/users/papantonis1/anaconda3/envs/cool_notebook/lib/python3.10/site-packages/coolpuppy/coolpup.py:919: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chroffset = self.clr.offset(region[0])
# INFO:coolpuppy:('chr8', 'chr8'): 33
# INFO:coolpuppy:('chr7', 'chr7'): 46
# INFO:coolpuppy:('chr6', 'chr6'): 41
# INFO:coolpuppy:('chr5', 'chr5'): 37
# INFO:coolpuppy:('chr9', 'chr9'): 26
# INFO:coolpuppy:('chr3', 'chr3'): 44
# INFO:coolpuppy:('chr4', 'chr4'): 47
# INFO:coolpuppy:('chr1', 'chr1'): 58
# INFO:coolpuppy:('chr10', 'chr10'): 43
# INFO:coolpuppy:('chr11', 'chr11'): 42
# INFO:coolpuppy:('chr2', 'chr2'): 75
# INFO:coolpuppy:('chr15', 'chr15'): 17
# INFO:coolpuppy:('chr14', 'chr14'): 12
# INFO:coolpuppy:('chr12', 'chr12'): 36
# INFO:coolpuppy:('chr17', 'chr17'): 28
# INFO:coolpuppy:('chr13', 'chr13'): 21
# INFO:coolpuppy:('chr16', 'chr16'): 19
# INFO:coolpuppy:('chrY', 'chrY'): 5
# INFO:coolpuppy:('chr19', 'chr19'): 20
# INFO:coolpuppy:('chr22', 'chr22'): 15
# INFO:coolpuppy:('chr21', 'chr21'): 4
# INFO:coolpuppy:('chr20', 'chr20'): 29
# INFO:coolpuppy:('chr18', 'chr18'): 12
# INFO:coolpuppy:('chrX', 'chrX'): 12
# INFO:coolpuppy:Total number of piled up windows: 722
# /usr/users/papantonis1/anaconda3/envs/cool_notebook/lib/python3.10/site-packages/coolpuppy/coolpup.py:2224: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pups["expected"] = pups["expected"].fillna(False)
# /usr/users/papantonis1/anaconda3/envs/cool_notebook/lib/python3.10/site-packages/coolpuppy/lib/io.py:47: FutureWarning: Starting with pandas version 3.0 all arguments of to_hdf except for the argument 'path_or_buf' will be keyword-only.
#   df[
# INFO:coolpuppy:Saved output to unique_cooldots_ctrl_fixed.npz

# %%
import subprocess

def plot_pileup(input_npz, output_pdf):
    """
    Run plotpup.py using the 'cool_notebook' conda environment.
    """
    plotpup_script = "/usr/users/papantonis1/anaconda3/envs/cool_notebook/bin/plotpup.py"
    cmd = [
        "bash", "-c",
        f"source ~/anaconda3/etc/profile.d/conda.sh && conda activate cool_notebook && python {plotpup_script} --input_pups {input_npz} --output {output_pdf}"
    ]
    subprocess.run(cmd, check=True)

# %%
plot_pileup("/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/merged_loops_3tools/unique_cooldots_ctrl_fixed.npz", "unique_cooldots_ctrl_fixed.pdf")
# Out:
# INFO:fontTools.subset:maxp pruned
# INFO:fontTools.subset:cmap pruned
# INFO:fontTools.subset:kern dropped
# INFO:fontTools.subset:post pruned
# INFO:fontTools.subset:FFTM dropped
# INFO:fontTools.subset:GPOS pruned
# INFO:fontTools.subset:GSUB pruned
# INFO:fontTools.subset:glyf pruned
# INFO:fontTools.subset:Added gid0 to subset
# INFO:fontTools.subset:Added first four glyphs to subset
# INFO:fontTools.subset:Closing glyph list over 'MATH': 10 glyphs before
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'four', 'nonmarkingreturn', 'one', 'period', 'seven', 'space', 'three', 'zero']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 17, 19, 20, 22, 23, 26]
# INFO:fontTools.subset:Closed glyph list over 'MATH': 10 glyphs after
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'four', 'nonmarkingreturn', 'one', 'period', 'seven', 'space', 'three', 'zero']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 17, 19, 20, 22, 23, 26]
# INFO:fontTools.subset:Closing glyph list over 'GSUB': 10 glyphs before
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'four', 'nonmarkingreturn', 'one', 'period', 'seven', 'space', 'three', 'zero']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 17, 19, 20, 22, 23, 26]
# INFO:fontTools.subset:Closed glyph list over 'GSUB': 10 glyphs after
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'four', 'nonmarkingreturn', 'one', 'period', 'seven', 'space', 'three', 'zero']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 17, 19, 20, 22, 23, 26]
# INFO:fontTools.subset:Closing glyph list over 'glyf': 10 glyphs before
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'four', 'nonmarkingreturn', 'one', 'period', 'seven', 'space', 'three', 'zero']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 17, 19, 20, 22, 23, 26]
# INFO:fontTools.subset:Closed glyph list over 'glyf': 10 glyphs after
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'four', 'nonmarkingreturn', 'one', 'period', 'seven', 'space', 'three', 'zero']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 17, 19, 20, 22, 23, 26]
# INFO:fontTools.subset:Retaining 10 glyphs
# INFO:fontTools.subset:head subsetting not needed
# INFO:fontTools.subset:hhea subsetting not needed
# INFO:fontTools.subset:maxp subsetting not needed
# INFO:fontTools.subset:OS/2 subsetting not needed
# INFO:fontTools.subset:hmtx subsetted
# INFO:fontTools.subset:cmap subsetted
# INFO:fontTools.subset:fpgm subsetting not needed
# INFO:fontTools.subset:prep subsetting not needed
# INFO:fontTools.subset:cvt  subsetting not needed
# INFO:fontTools.subset:loca subsetting not needed
# INFO:fontTools.subset:post subsetted
# INFO:fontTools.subset:gasp subsetting not needed
# INFO:fontTools.subset:MATH subsetted
# INFO:fontTools.subset:GDEF subsetted
# INFO:fontTools.subset:GPOS subsetted
# INFO:fontTools.subset:GSUB subsetted
# INFO:fontTools.subset:name subsetting not needed
# INFO:fontTools.subset:glyf subsetted
# INFO:fontTools.subset:head pruned
# INFO:fontTools.subset:OS/2 Unicode ranges pruned: [0]
# INFO:fontTools.subset:OS/2 CodePage ranges pruned: [0]
# INFO:fontTools.subset:glyf pruned
# INFO:fontTools.subset:GDEF pruned
# INFO:fontTools.subset:GPOS pruned
# INFO:fontTools.subset:GSUB pruned
# INFO:fontTools.subset:name pruned
# INFO:coolpuppy:Saved output to unique_cooldots_ctrl_fixed.pdf
