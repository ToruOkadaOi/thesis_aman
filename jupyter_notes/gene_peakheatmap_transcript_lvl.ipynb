# %%
# doing it individually 
# H3K27me3 ctrl bigwig - gene upregulated
## using subprocess
import subprocess

result = subprocess.run([
    "computeMatrix", "scale-regions",
    "-S", "/usr/users/papantonis1/aman/microc_data/cut_n_tag/nadine_cut_tag/nadine_cut_tag/C_H3K27me3_results/Aligned_files/Bigwig_scaled/C_H3K27me3.bw_RPGC.bw",
    "-R", "/usr/users/papantonis1/aman/rnaseq_data/upregulated_transcript_level_genebodies.bed",
    "-b", "2000",       # kb upstream of TSS
    "-a", "2000",       # kb downstream of TES
    "-m", "3000",      # gene body length to scale to
    "--skipZeros",
    "--missingDataAsZero",
    "--outFileName", "ctrl_H3K27me3_upregulated_geneBody_matrix.gz"
], capture_output=True, text=True)

print(result.stdout)
print("STDERR:", result.stderr)
if result.returncode != 0:
    print("Error: computeMatrix failed")

subprocess.run([
    "plotHeatmap",
    "-m", "ctrl_H3K27me3_upregulated_geneBody_matrix.gz",
    "-out", "/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/ctrl_H3K27me3_upregulated_gene_heatmap.png",
    "--colorMap", "YlGnBu",
    "--heatmapHeight", "15",
    "--regionsLabel", "Upregulated genes",
    "--samplesLabel", "H3K27me3 signal",
    "--plotTitle", "H3K27me3 signal(control) at upregulated genes",
    "--heatmapWidth", "6",
    "--heatmapHeight", "30"
])
# Out:
# STDERR: Skipping ENST00000641939.1, due to being absent in the computeMatrix output.
# Skipping ENST00000482968.1, due to being absent in the computeMatrix output.
# Skipping ENST00000477264.1, due to being absent in the computeMatrix output.
# Skipping ENST00000464286.1, due to being absent in the computeMatrix output.
# Skipping ENST00000483508.5, due to being absent in the computeMatrix output.
# Skipping ENST00000495777.5, due to being absent in the computeMatrix output.
# Skipping ENST00000638051.1, due to being absent in the computeMatrix output.
# Skipping ENST00000303577.7, due to being absent in the computeMatrix output.
# Skipping ENST00000485563.1, due to being absent in the computeMatrix output.
# Skipping ENST00000481732.5, due to being absent in the computeMatrix output.
# Skipping ENST00000461876.5, due to being absent in the computeMatrix output.
# Skipping ENST00000497357.1, due to being absent in the computeMatrix output.
# Skipping ENST00000485503.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676398.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675488.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675624.1, due to being absent in the computeMatrix output.
# Skipping ENST00000674560.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675733.1, due to being absent in the computeMatrix output.
# Skipping ENST00000248553.7, due to being absent in the computeMatrix output.
# Skipping ENST00000674547.1, due to being absent in the computeMatrix output.
# Skipping ENST00000674638.1, due to being absent in the computeMatrix output.
# Skipping ENST00000674965.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675134.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675226.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675538.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675906.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676231.1, due to being absent in the computeMatrix output.
# Skipping ENST00000447574.1, due to being absent in the computeMatrix output.
# Skipping ENST00000674650.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676195.1, due to being absent in the computeMatrix output.
# Skipping ENST00000429938.1, due to being absent in the computeMatrix output.
# Skipping ENST00000404944.3, due to being absent in the computeMatrix output.
# Skipping ENST00000680150.1, due to being absent in the computeMatrix output.
# Skipping ENST00000478776.2, due to being absent in the computeMatrix output.
# Skipping ENST00000603484.1, due to being absent in the computeMatrix output.
# Skipping ENST00000469172.5, due to being absent in the computeMatrix output.
# Skipping ENST00000461310.5, due to being absent in the computeMatrix output.
# Skipping ENST00000265866.12, due to being absent in the computeMatrix output.
# Skipping ENST00000480987.5, due to being absent in the computeMatrix output.
# Skipping ENST00000486854.5, due to being absent in the computeMatrix output.
# Skipping ENST00000467249.1, due to being absent in the computeMatrix output.
# Skipping ENST00000354695.5, due to being absent in the computeMatrix output.
# Skipping ENST00000481819.5, due to being absent in the computeMatrix output.
# Skipping ENST00000491200.5, due to being absent in the computeMatrix output.
# Skipping ENST00000490442.5, due to being absent in the computeMatrix output.
# Skipping ENST00000478698.1, due to being absent in the computeMatrix output.
# Skipping ENST00000484853.1, due to being absent in the computeMatrix output.
# Skipping ENST00000530493.1, due to being absent in the computeMatrix output.
# Skipping ENST00000525604.1, due to being absent in the computeMatrix output.
# Skipping ENST00000528503.1, due to being absent in the computeMatrix output.
# Skipping ENST00000531563.1, due to being absent in the computeMatrix output.
# Skipping ENST00000545732.1, due to being absent in the computeMatrix output.
# Skipping ENST00000615278.1, due to being absent in the computeMatrix output.
# Skipping ENST00000557969.1, due to being absent in the computeMatrix output.
# Skipping ENST00000558947.1, due to being absent in the computeMatrix output.
# Skipping ENST00000448553.5, due to being absent in the computeMatrix output.
# Skipping ENST00000457418.5, due to being absent in the computeMatrix output.
# Skipping ENST00000299969.10, due to being absent in the computeMatrix output.
# Skipping ENST00000319327.7, due to being absent in the computeMatrix output.
# Skipping ENST00000412697.1, due to being absent in the computeMatrix output.
# Skipping ENST00000476490.1, due to being absent in the computeMatrix output.
# Skipping ENST00000287667.12, due to being absent in the computeMatrix output.
# Skipping ENST00000566720.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566883.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566917.1, due to being absent in the computeMatrix output.
# Skipping ENST00000565655.1, due to being absent in the computeMatrix output.
# Skipping ENST00000566823.1, due to being absent in the computeMatrix output.
# Skipping ENST00000576589.1, due to being absent in the computeMatrix output.
# Skipping ENST00000572830.5, due to being absent in the computeMatrix output.
# Skipping ENST00000570519.5, due to being absent in the computeMatrix output.
# Skipping ENST00000576427.1, due to being absent in the computeMatrix output.
# Skipping ENST00000574157.5, due to being absent in the computeMatrix output.
# Skipping ENST00000572932.1, due to being absent in the computeMatrix output.
# Skipping ENST00000573635.1, due to being absent in the computeMatrix output.
# Skipping ENST00000570732.2, due to being absent in the computeMatrix output.
# Skipping ENST00000570346.1, due to being absent in the computeMatrix output.
# Skipping ENST00000566501.5, due to being absent in the computeMatrix output.
# Skipping ENST00000395587.5, due to being absent in the computeMatrix output.
# Skipping ENST00000569690.5, due to being absent in the computeMatrix output.
# Skipping ENST00000331666.11, due to being absent in the computeMatrix output.
# Skipping ENST00000564243.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566866.5, due to being absent in the computeMatrix output.
# Skipping ENST00000563139.5, due to being absent in the computeMatrix output.
# Skipping ENST00000568426.1, due to being absent in the computeMatrix output.
# Skipping ENST00000565099.1, due to being absent in the computeMatrix output.
# Skipping ENST00000565932.5, due to being absent in the computeMatrix output.
# Skipping ENST00000564839.1, due to being absent in the computeMatrix output.
# Skipping ENST00000566519.1, due to being absent in the computeMatrix output.
# Skipping ENST00000569005.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566086.1, due to being absent in the computeMatrix output.
# Skipping ENST00000561916.2, due to being absent in the computeMatrix output.
# Skipping ENST00000573672.1, due to being absent in the computeMatrix output.
# Skipping ENST00000332499.4, due to being absent in the computeMatrix output.
# Skipping ENST00000572803.1, due to being absent in the computeMatrix output.
# Skipping ENST00000570716.1, due to being absent in the computeMatrix output.
# Skipping ENST00000573556.1, due to being absent in the computeMatrix output.
# Skipping ENST00000582747.1, due to being absent in the computeMatrix output.
# Skipping ENST00000497303.1, due to being absent in the computeMatrix output.
# Skipping ENST00000558528.1, due to being absent in the computeMatrix output.
# Skipping ENST00000560173.1, due to being absent in the computeMatrix output.
# Skipping ENST00000589990.1, due to being absent in the computeMatrix output.
# Skipping ENST00000585325.5, due to being absent in the computeMatrix output.
# Skipping ENST00000592445.1, due to being absent in the computeMatrix output.
# Skipping ENST00000585540.1, due to being absent in the computeMatrix output.
# Skipping ENST00000587290.5, due to being absent in the computeMatrix output.
# Skipping ENST00000590098.1, due to being absent in the computeMatrix output.
# Skipping ENST00000592435.1, due to being absent in the computeMatrix output.
# Skipping ENST00000601097.1, due to being absent in the computeMatrix output.
# Skipping ENST00000469291.1, due to being absent in the computeMatrix output.
# Skipping ENST00000492367.1, due to being absent in the computeMatrix output.
# Skipping ENST00000551747.1, due to being absent in the computeMatrix output.
# Skipping ENST00000598022.1, due to being absent in the computeMatrix output.
# Skipping ENST00000495398.1, due to being absent in the computeMatrix output.
# Skipping ENST00000472318.1, due to being absent in the computeMatrix output.
# Skipping ENST00000471037.1, due to being absent in the computeMatrix output.
# Skipping ENST00000471342.1, due to being absent in the computeMatrix output.
# Skipping ENST00000375722.5, due to being absent in the computeMatrix output.
# Skipping ENST00000326587.12, due to being absent in the computeMatrix output.
# Skipping ENST00000375695.2, due to being absent in the computeMatrix output.
# Skipping ENST00000470461.1, due to being absent in the computeMatrix output.
# Skipping ENST00000494718.5, due to being absent in the computeMatrix output.
# Skipping ENST00000485420.5, due to being absent in the computeMatrix output.
# Skipping ENST00000482188.1, due to being absent in the computeMatrix output.
# Skipping ENST00000482599.1, due to being absent in the computeMatrix output.
# Skipping ENST00000473931.1, due to being absent in the computeMatrix output.
# CompletedProcess(args=['plotHeatmap', '-m', 'ctrl_H3K27me3_upregulated_geneBody_matrix.gz', '-out', '/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/ctrl_H3K27me3_upregulated_gene_heatmap.png', '--colorMap', 'YlGnBu', '--heatmapHeight', '15', '--regionsLabel', 'Upregulated genes', '--samplesLabel', 'H3K27me3 signal', '--plotTitle', 'H3K27me3 signal(control) at upregulated genes', '--heatmapWidth', '6', '--heatmapHeight', '30'], returncode=0)

# %% [markdown]
# ---

# %%
# doing it individually 
# H3K27me3 ctrl bigwig - gene downregulated

## using subprocess
import subprocess

result = subprocess.run([
    "computeMatrix", "scale-regions",
    "-S", "/usr/users/papantonis1/aman/microc_data/cut_n_tag/nadine_cut_tag/nadine_cut_tag/C_H3K27me3_results/Aligned_files/Bigwig_scaled/C_H3K27me3.bw_RPGC.bw",
    "-R", "/usr/users/papantonis1/aman/rnaseq_data/downregulated_transcript_level_genebodies.bed",
    "-b", "2000",       # kb upstream of TSS
    "-a", "2000",       # kb downstream of TES
    "-m", "3000",      # gene body length to scale to
    "--skipZeros",
    "--missingDataAsZero",
    "--outFileName", "ctrl_H3K27me3_downregulated_geneBody_matrix.gz"
], capture_output=True, text=True)

print(result.stdout)
print("STDERR:", result.stderr)
if result.returncode != 0:
    print("Error: computeMatrix failed")

subprocess.run([
    "plotHeatmap",
    "-m", "ctrl_H3K27me3_downregulated_geneBody_matrix.gz",
    "-out", "/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/ctrl_H3K27me3_downregulated_gene_heatmap.png",
    "--colorMap", "YlGnBu",
    "--heatmapHeight", "15",
    "--regionsLabel", "Downregulated genes",
    "--samplesLabel", "H3K27me3 signal",
    "--plotTitle", "H3K27me3 signal(control) at downregulated genes",
    "--heatmapWidth", "6",
    "--heatmapHeight", "30"
])
# Out:
# STDERR: Skipping ENST00000486046.5, due to being absent in the computeMatrix output.
# Skipping ENST00000671291.1, due to being absent in the computeMatrix output.
# Skipping ENST00000493901.6, due to being absent in the computeMatrix output.
# Skipping ENST00000470890.1, due to being absent in the computeMatrix output.
# Skipping ENST00000476509.1, due to being absent in the computeMatrix output.
# Skipping ENST00000495230.2, due to being absent in the computeMatrix output.
# Skipping ENST00000516404.1, due to being absent in the computeMatrix output.
# Skipping ENST00000364089.1, due to being absent in the computeMatrix output.
# Skipping ENST00000391100.1, due to being absent in the computeMatrix output.
# Skipping ENST00000430686.2, due to being absent in the computeMatrix output.
# Skipping ENST00000534736.1, due to being absent in the computeMatrix output.
# Skipping ENST00000529297.1, due to being absent in the computeMatrix output.
# Skipping ENST00000582661.1, due to being absent in the computeMatrix output.
# Skipping ENST00000376347.1, due to being absent in the computeMatrix output.
# Skipping ENST00000365128.1, due to being absent in the computeMatrix output.
# Skipping ENST00000527339.1, due to being absent in the computeMatrix output.
# Skipping ENST00000391141.1, due to being absent in the computeMatrix output.
# Skipping ENST00000568456.1, due to being absent in the computeMatrix output.
# Skipping ENST00000560029.5, due to being absent in the computeMatrix output.
# Skipping ENST00000584923.1, due to being absent in the computeMatrix output.
# Skipping ENST00000571722.3, due to being absent in the computeMatrix output.
# Skipping ENST00000580533.1, due to being absent in the computeMatrix output.
# Skipping ENST00000363922.1, due to being absent in the computeMatrix output.
# CompletedProcess(args=['plotHeatmap', '-m', 'ctrl_H3K27me3_downregulated_geneBody_matrix.gz', '-out', '/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/ctrl_H3K27me3_downregulated_gene_heatmap.png', '--colorMap', 'YlGnBu', '--heatmapHeight', '15', '--regionsLabel', 'Downregulated genes', '--samplesLabel', 'H3K27me3 signal', '--plotTitle', 'H3K27me3 signal(control) at downregulated genes', '--heatmapWidth', '6', '--heatmapHeight', '30'], returncode=0)

# %% [markdown]
# ---

# %%
# doing it individually 
# H3K27me3 ctrl bigwig - gene upregulated
## using subprocess
import subprocess

result = subprocess.run([
    "computeMatrix", "scale-regions",
    "-S", "/usr/users/papantonis1/aman/microc_data/cut_n_tag/nadine_cut_tag/nadine_cut_tag/CPI_H3K27me3_results/Aligned_files/Bigwig_scaled/CPI_H3K27me3.bw_RPGC.bw",
    "-R", "/usr/users/papantonis1/aman/rnaseq_data/upregulated_transcript_level_genebodies.bed",
    "-b", "2000",       # kb upstream of TSS
    "-a", "2000",       # kb downstream of TES
    "-m", "3000",      # gene body length to scale to
    "--skipZeros",
    "--missingDataAsZero",
    "--outFileName", "cpi_H3K27me3_upregulated_geneBody_matrix.gz"
], capture_output=True, text=True)

print(result.stdout)
print("STDERR:", result.stderr)
if result.returncode != 0:
    print("Error: computeMatrix failed")

subprocess.run([
    "plotHeatmap",
    "-m", "cpi_H3K27me3_upregulated_geneBody_matrix.gz",
    "-out", "/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/cpi_H3K27me3_upregulated_gene_heatmap.png",
    "--colorMap", "YlGnBu",
    "--heatmapHeight", "15",
    "--regionsLabel", "Upregulated genes",
    "--samplesLabel", "H3K27me3 signal",
    "--plotTitle", "H3K27me3 signal(cpi) at upregulated genes",
    "--heatmapWidth", "6",
    "--heatmapHeight", "30"
])
# Out:
# STDERR: Skipping ENST00000310955.11, due to being absent in the computeMatrix output.
# Skipping ENST00000372462.1, due to being absent in the computeMatrix output.
# Skipping ENST00000478882.1, due to being absent in the computeMatrix output.
# Skipping ENST00000482046.1, due to being absent in the computeMatrix output.
# Skipping ENST00000641847.1, due to being absent in the computeMatrix output.
# Skipping ENST00000641455.1, due to being absent in the computeMatrix output.
# Skipping ENST00000461729.1, due to being absent in the computeMatrix output.
# Skipping ENST00000467015.1, due to being absent in the computeMatrix output.
# Skipping ENST00000492568.1, due to being absent in the computeMatrix output.
# Skipping ENST00000485149.1, due to being absent in the computeMatrix output.
# Skipping ENST00000634645.1, due to being absent in the computeMatrix output.
# Skipping ENST00000634564.1, due to being absent in the computeMatrix output.
# Skipping ENST00000498013.1, due to being absent in the computeMatrix output.
# Skipping ENST00000444305.5, due to being absent in the computeMatrix output.
# Skipping ENST00000488712.5, due to being absent in the computeMatrix output.
# Skipping ENST00000236959.14, due to being absent in the computeMatrix output.
# Skipping ENST00000443953.5, due to being absent in the computeMatrix output.
# Skipping ENST00000435675.5, due to being absent in the computeMatrix output.
# Skipping ENST00000427397.5, due to being absent in the computeMatrix output.
# Skipping ENST00000413174.1, due to being absent in the computeMatrix output.
# Skipping ENST00000446622.5, due to being absent in the computeMatrix output.
# Skipping ENST00000426233.1, due to being absent in the computeMatrix output.
# Skipping ENST00000479093.5, due to being absent in the computeMatrix output.
# Skipping ENST00000467388.1, due to being absent in the computeMatrix output.
# Skipping ENST00000459796.1, due to being absent in the computeMatrix output.
# Skipping ENST00000442048.3, due to being absent in the computeMatrix output.
# Skipping ENST00000478734.1, due to being absent in the computeMatrix output.
# Skipping ENST00000282388.4, due to being absent in the computeMatrix output.
# Skipping ENST00000397056.1, due to being absent in the computeMatrix output.
# Skipping ENST00000462728.1, due to being absent in the computeMatrix output.
# Skipping ENST00000394631.7, due to being absent in the computeMatrix output.
# Skipping ENST00000506840.5, due to being absent in the computeMatrix output.
# Skipping ENST00000226796.7, due to being absent in the computeMatrix output.
# Skipping ENST00000503671.2, due to being absent in the computeMatrix output.
# Skipping ENST00000513497.1, due to being absent in the computeMatrix output.
# Skipping ENST00000502338.1, due to being absent in the computeMatrix output.
# Skipping ENST00000486695.1, due to being absent in the computeMatrix output.
# Skipping ENST00000459624.1, due to being absent in the computeMatrix output.
# Skipping ENST00000647981.1, due to being absent in the computeMatrix output.
# Skipping ENST00000684536.1, due to being absent in the computeMatrix output.
# Skipping ENST00000683687.1, due to being absent in the computeMatrix output.
# Skipping ENST00000684674.1, due to being absent in the computeMatrix output.
# Skipping ENST00000496955.1, due to being absent in the computeMatrix output.
# Skipping ENST00000476704.1, due to being absent in the computeMatrix output.
# Skipping ENST00000461593.5, due to being absent in the computeMatrix output.
# Skipping ENST00000468181.1, due to being absent in the computeMatrix output.
# Skipping ENST00000485503.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676398.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675488.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675624.1, due to being absent in the computeMatrix output.
# Skipping ENST00000674560.1, due to being absent in the computeMatrix output.
# Skipping ENST00000675733.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676195.1, due to being absent in the computeMatrix output.
# Skipping ENST00000404944.3, due to being absent in the computeMatrix output.
# Skipping ENST00000680219.1, due to being absent in the computeMatrix output.
# Skipping ENST00000680296.1, due to being absent in the computeMatrix output.
# Skipping ENST00000680150.1, due to being absent in the computeMatrix output.
# Skipping ENST00000478776.2, due to being absent in the computeMatrix output.
# Skipping ENST00000681087.1, due to being absent in the computeMatrix output.
# Skipping ENST00000679718.1, due to being absent in the computeMatrix output.
# Skipping ENST00000679488.1, due to being absent in the computeMatrix output.
# Skipping ENST00000481819.5, due to being absent in the computeMatrix output.
# Skipping ENST00000491200.5, due to being absent in the computeMatrix output.
# Skipping ENST00000490442.5, due to being absent in the computeMatrix output.
# Skipping ENST00000478698.1, due to being absent in the computeMatrix output.
# Skipping ENST00000495196.1, due to being absent in the computeMatrix output.
# Skipping ENST00000493143.1, due to being absent in the computeMatrix output.
# Skipping ENST00000633965.1, due to being absent in the computeMatrix output.
# Skipping ENST00000484853.1, due to being absent in the computeMatrix output.
# Skipping ENST00000531873.5, due to being absent in the computeMatrix output.
# Skipping ENST00000525209.5, due to being absent in the computeMatrix output.
# Skipping ENST00000531110.6, due to being absent in the computeMatrix output.
# Skipping ENST00000525685.6, due to being absent in the computeMatrix output.
# Skipping ENST00000534296.5, due to being absent in the computeMatrix output.
# Skipping ENST00000533222.5, due to being absent in the computeMatrix output.
# Skipping ENST00000525241.1, due to being absent in the computeMatrix output.
# Skipping ENST00000524922.1, due to being absent in the computeMatrix output.
# Skipping ENST00000525348.1, due to being absent in the computeMatrix output.
# Skipping ENST00000526553.6, due to being absent in the computeMatrix output.
# Skipping ENST00000534082.1, due to being absent in the computeMatrix output.
# Skipping ENST00000525293.5, due to being absent in the computeMatrix output.
# Skipping ENST00000528672.1, due to being absent in the computeMatrix output.
# Skipping ENST00000532339.1, due to being absent in the computeMatrix output.
# Skipping ENST00000531141.1, due to being absent in the computeMatrix output.
# Skipping ENST00000533860.5, due to being absent in the computeMatrix output.
# Skipping ENST00000530493.1, due to being absent in the computeMatrix output.
# Skipping ENST00000525604.1, due to being absent in the computeMatrix output.
# Skipping ENST00000528503.1, due to being absent in the computeMatrix output.
# Skipping ENST00000531563.1, due to being absent in the computeMatrix output.
# Skipping ENST00000526732.5, due to being absent in the computeMatrix output.
# Skipping ENST00000536090.1, due to being absent in the computeMatrix output.
# Skipping ENST00000535804.1, due to being absent in the computeMatrix output.
# Skipping ENST00000548553.1, due to being absent in the computeMatrix output.
# Skipping ENST00000550502.1, due to being absent in the computeMatrix output.
# Skipping ENST00000547104.1, due to being absent in the computeMatrix output.
# Skipping ENST00000332160.5, due to being absent in the computeMatrix output.
# Skipping ENST00000550097.1, due to being absent in the computeMatrix output.
# Skipping ENST00000615278.1, due to being absent in the computeMatrix output.
# Skipping ENST00000552920.1, due to being absent in the computeMatrix output.
# Skipping ENST00000463003.2, due to being absent in the computeMatrix output.
# Skipping ENST00000645174.2, due to being absent in the computeMatrix output.
# Skipping ENST00000361283.4, due to being absent in the computeMatrix output.
# Skipping ENST00000478022.3, due to being absent in the computeMatrix output.
# Skipping ENST00000700527.1, due to being absent in the computeMatrix output.
# Skipping ENST00000643483.2, due to being absent in the computeMatrix output.
# Skipping ENST00000700528.1, due to being absent in the computeMatrix output.
# Skipping ENST00000644294.2, due to being absent in the computeMatrix output.
# Skipping ENST00000473577.1, due to being absent in the computeMatrix output.
# Skipping ENST00000557969.1, due to being absent in the computeMatrix output.
# Skipping ENST00000557725.5, due to being absent in the computeMatrix output.
# Skipping ENST00000559966.1, due to being absent in the computeMatrix output.
# Skipping ENST00000287667.12, due to being absent in the computeMatrix output.
# Skipping ENST00000566720.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566883.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566917.1, due to being absent in the computeMatrix output.
# Skipping ENST00000565655.1, due to being absent in the computeMatrix output.
# Skipping ENST00000566823.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676846.1, due to being absent in the computeMatrix output.
# Skipping ENST00000399336.9, due to being absent in the computeMatrix output.
# Skipping ENST00000677912.1, due to being absent in the computeMatrix output.
# Skipping ENST00000576589.1, due to being absent in the computeMatrix output.
# Skipping ENST00000678080.1, due to being absent in the computeMatrix output.
# Skipping ENST00000574894.2, due to being absent in the computeMatrix output.
# Skipping ENST00000679086.1, due to being absent in the computeMatrix output.
# Skipping ENST00000678538.1, due to being absent in the computeMatrix output.
# Skipping ENST00000678393.1, due to being absent in the computeMatrix output.
# Skipping ENST00000678192.1, due to being absent in the computeMatrix output.
# Skipping ENST00000677777.1, due to being absent in the computeMatrix output.
# Skipping ENST00000677260.1, due to being absent in the computeMatrix output.
# Skipping ENST00000676550.1, due to being absent in the computeMatrix output.
# Skipping ENST00000263012.10, due to being absent in the computeMatrix output.
# Skipping ENST00000575225.5, due to being absent in the computeMatrix output.
# Skipping ENST00000677163.1, due to being absent in the computeMatrix output.
# Skipping ENST00000677781.1, due to being absent in the computeMatrix output.
# Skipping ENST00000678148.1, due to being absent in the computeMatrix output.
# Skipping ENST00000572830.5, due to being absent in the computeMatrix output.
# Skipping ENST00000570519.5, due to being absent in the computeMatrix output.
# Skipping ENST00000576427.1, due to being absent in the computeMatrix output.
# Skipping ENST00000576269.1, due to being absent in the computeMatrix output.
# Skipping ENST00000576460.5, due to being absent in the computeMatrix output.
# Skipping ENST00000572033.1, due to being absent in the computeMatrix output.
# Skipping ENST00000574157.5, due to being absent in the computeMatrix output.
# Skipping ENST00000572932.1, due to being absent in the computeMatrix output.
# Skipping ENST00000573635.1, due to being absent in the computeMatrix output.
# Skipping ENST00000570732.2, due to being absent in the computeMatrix output.
# Skipping ENST00000570346.1, due to being absent in the computeMatrix output.
# Skipping ENST00000395587.5, due to being absent in the computeMatrix output.
# Skipping ENST00000569690.5, due to being absent in the computeMatrix output.
# Skipping ENST00000331666.11, due to being absent in the computeMatrix output.
# Skipping ENST00000564243.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566866.5, due to being absent in the computeMatrix output.
# Skipping ENST00000563139.5, due to being absent in the computeMatrix output.
# Skipping ENST00000568426.1, due to being absent in the computeMatrix output.
# Skipping ENST00000565099.1, due to being absent in the computeMatrix output.
# Skipping ENST00000565932.5, due to being absent in the computeMatrix output.
# Skipping ENST00000564839.1, due to being absent in the computeMatrix output.
# Skipping ENST00000566519.1, due to being absent in the computeMatrix output.
# Skipping ENST00000569005.5, due to being absent in the computeMatrix output.
# Skipping ENST00000566086.1, due to being absent in the computeMatrix output.
# Skipping ENST00000573672.1, due to being absent in the computeMatrix output.
# Skipping ENST00000571826.5, due to being absent in the computeMatrix output.
# Skipping ENST00000572134.1, due to being absent in the computeMatrix output.
# Skipping ENST00000575237.2, due to being absent in the computeMatrix output.
# Skipping ENST00000634839.1, due to being absent in the computeMatrix output.
# Skipping ENST00000636002.1, due to being absent in the computeMatrix output.
# Skipping ENST00000635899.1, due to being absent in the computeMatrix output.
# Skipping ENST00000582004.1, due to being absent in the computeMatrix output.
# Skipping ENST00000570716.1, due to being absent in the computeMatrix output.
# Skipping ENST00000576632.1, due to being absent in the computeMatrix output.
# Skipping ENST00000558528.1, due to being absent in the computeMatrix output.
# Skipping ENST00000597211.1, due to being absent in the computeMatrix output.
# Skipping ENST00000551747.1, due to being absent in the computeMatrix output.
# Skipping ENST00000548570.1, due to being absent in the computeMatrix output.
# Skipping ENST00000453574.1, due to being absent in the computeMatrix output.
# Skipping ENST00000479015.1, due to being absent in the computeMatrix output.
# Skipping ENST00000461865.1, due to being absent in the computeMatrix output.
# CompletedProcess(args=['plotHeatmap', '-m', 'cpi_H3K27me3_upregulated_geneBody_matrix.gz', '-out', '/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/cpi_H3K27me3_upregulated_gene_heatmap.png', '--colorMap', 'YlGnBu', '--heatmapHeight', '15', '--regionsLabel', 'Upregulated genes', '--samplesLabel', 'H3K27me3 signal', '--plotTitle', 'H3K27me3 signal(cpi) at upregulated genes', '--heatmapWidth', '6', '--heatmapHeight', '30'], returncode=0)

# %% [markdown]
# ---

# %%
# doing it individually 
# H3K27me3 ctrl bigwig - gene upregulated
## using subprocess
import subprocess

result = subprocess.run([
    "computeMatrix", "scale-regions",
    "-S", "/usr/users/papantonis1/aman/microc_data/cut_n_tag/nadine_cut_tag/nadine_cut_tag/CPI_H3K27me3_results/Aligned_files/Bigwig_scaled/CPI_H3K27me3.bw_RPGC.bw",
    "-R", "/usr/users/papantonis1/aman/rnaseq_data/downregulated_transcript_level_genebodies.bed",
    "-b", "2000",       # 3kb upstream of TSS
    "-a", "2000",       # 3kb downstream of TES
    "-m", "3000",      # gene body length to scale to
    "--skipZeros",
    "--missingDataAsZero",
    "--outFileName", "cpi_H3K27me3_downregulated_geneBody_matrix.gz"
], capture_output=True, text=True)

print(result.stdout)
print("STDERR:", result.stderr)
if result.returncode != 0:
    print("Error: computeMatrix failed")

subprocess.run([
    "plotHeatmap",
    "-m", "cpi_H3K27me3_downregulated_geneBody_matrix.gz",
    "-out", "/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/cpi_H3K27me3_downregulated_gene_heatmap.png",
    "--colorMap", "YlGnBu",
    "--heatmapHeight", "15",
    "--regionsLabel", "Upregulated genes",
    "--samplesLabel", "H3K27me3 signal",
    "--plotTitle", "H3K27me3 signal(cpi) at downregulated genes",
    "--heatmapWidth", "6",
    "--heatmapHeight", "30"
])
# Out:
# STDERR: Skipping ENST00000467204.1, due to being absent in the computeMatrix output.
# Skipping ENST00000492035.1, due to being absent in the computeMatrix output.
# Skipping ENST00000386037.1, due to being absent in the computeMatrix output.
# Skipping ENST00000515982.1, due to being absent in the computeMatrix output.
# Skipping ENST00000495252.1, due to being absent in the computeMatrix output.
# Skipping ENST00000696131.1, due to being absent in the computeMatrix output.
# Skipping ENST00000401931.1, due to being absent in the computeMatrix output.
# Skipping ENST00000696132.1, due to being absent in the computeMatrix output.
# Skipping ENST00000483500.1, due to being absent in the computeMatrix output.
# Skipping ENST00000307407.8, due to being absent in the computeMatrix output.
# Skipping ENST00000503289.1, due to being absent in the computeMatrix output.
# Skipping ENST00000364089.1, due to being absent in the computeMatrix output.
# Skipping ENST00000526643.1, due to being absent in the computeMatrix output.
# Skipping ENST00000376347.1, due to being absent in the computeMatrix output.
# Skipping ENST00000495062.2, due to being absent in the computeMatrix output.
# Skipping ENST00000263103.1, due to being absent in the computeMatrix output.
# Skipping ENST00000365128.1, due to being absent in the computeMatrix output.
# Skipping ENST00000391141.1, due to being absent in the computeMatrix output.
# Skipping ENST00000536313.2, due to being absent in the computeMatrix output.
# Skipping ENST00000545964.1, due to being absent in the computeMatrix output.
# Skipping ENST00000538454.2, due to being absent in the computeMatrix output.
# Skipping ENST00000536997.1, due to being absent in the computeMatrix output.
# Skipping ENST00000540476.5, due to being absent in the computeMatrix output.
# Skipping ENST00000541686.5, due to being absent in the computeMatrix output.
# Skipping ENST00000393543.7, due to being absent in the computeMatrix output.
# Skipping ENST00000430606.3, due to being absent in the computeMatrix output.
# Skipping ENST00000545724.2, due to being absent in the computeMatrix output.
# Skipping ENST00000541087.1, due to being absent in the computeMatrix output.
# Skipping ENST00000410557.1, due to being absent in the computeMatrix output.
# Skipping ENST00000382437.8, due to being absent in the computeMatrix output.
# Skipping ENST00000569184.1, due to being absent in the computeMatrix output.
# Skipping ENST00000568456.1, due to being absent in the computeMatrix output.
# Skipping ENST00000560029.5, due to being absent in the computeMatrix output.
# Skipping ENST00000584923.1, due to being absent in the computeMatrix output.
# Skipping ENST00000571722.3, due to being absent in the computeMatrix output.
# Skipping ENST00000580533.1, due to being absent in the computeMatrix output.
# Skipping ENST00000363922.1, due to being absent in the computeMatrix output.
# CompletedProcess(args=['plotHeatmap', '-m', 'cpi_H3K27me3_downregulated_geneBody_matrix.gz', '-out', '/usr/users/papantonis1/aman/microc_project/loop_calling_premade_hic/jupyter_notes/heatmap_deeptoools/cpi_H3K27me3_downregulated_gene_heatmap.png', '--colorMap', 'YlGnBu', '--heatmapHeight', '15', '--regionsLabel', 'Upregulated genes', '--samplesLabel', 'H3K27me3 signal', '--plotTitle', 'H3K27me3 signal(cpi) at downregulated genes', '--heatmapWidth', '6', '--heatmapHeight', '30'], returncode=0)
