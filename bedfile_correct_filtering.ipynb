# %%
import pandas as pd

path = "/usr/users/papantonis1/aman/rnaseq_data/upregulated_transcript_level_TSS.bed_filtered.bed"
df = pd.read_csv(path, sep="\t", header=None)
df.iloc[:, :3].to_csv(path, sep="\t", header=False, index=False)

# %%
path = "/usr/users/papantonis1/aman/rnaseq_data/downregulated_transcript_level_TSS.bed_filtered.bed"
df = pd.read_csv(path, sep="\t", header=None)
df.iloc[:, :3].to_csv(path, sep="\t", header=False, index=False)
