# %%
import pandas as pd

# Load your file
df = pd.read_csv("/usr/users/papantonis1/aman/rnaseq_data/upregulated_genes_deseq_auxincpi.txt", sep="\t")

# Count hgnc_symbol entries that are *real genes* (not ENSG… placeholders)
regular = df[~df["hgnc_symbol"].str.startswith("ENSG", na=False)]
print("Regular genes:", len(regular))
print("Total entries:", len(df))
# Out:
# Regular genes: 5780
# Total entries: 9790

# %%
# Load your file
df = pd.read_csv("/usr/users/papantonis1/aman/rnaseq_data/downregulated_genes_deseq_auxincpi.txt", sep="\t")

# Count hgnc_symbol entries that are *real genes* (not ENSG… placeholders)
regular = df[~df["hgnc_symbol"].str.startswith("ENSG", na=False)]
print("Regular genes:", len(regular))
print("Total entries:", len(df))
# Out:
# Regular genes: 3571
# Total entries: 5198
