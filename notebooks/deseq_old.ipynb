"/usr/users/papantonis1/aman/rnaseq_data/star_results/S55_Aligned.sortedByCoord.out.bam"
# [2] "/usr/users/papantonis1/aman/rnaseq_data/star_results/S56_Aligned.sortedByCoord.out.bam"
# [3] "/usr/users/papantonis1/aman/rnaseq_data/star_results/S57_Aligned.sortedByCoord.out.bam"
# [4] "/usr/users/papantonis1/aman/rnaseq_data/star_results/S58_Aligned.sortedByCoord.out.bam"
# [5] "/usr/users/papantonis1/aman/rnaseq_data/star_results/S59_Aligned.sortedByCoord.out.bam"
# [6] "/usr/users/papantonis1/aman/rnaseq_data/star_results/S60_Aligned.sortedByCoord.out.bam"

# %%
condition <- factor(c("AuxinCPI", "AuxinCPI", "CPI", "CPI", "control", "control"),
                    levels = c("control", "CPI", "AuxinCPI"))

# control is the reference level

# %%
coldata <- data.frame(row.names = colnames(count_matrix),
                      condition = condition)
coldata
# Out:
#                                                                                        condition
# /usr/users/papantonis1/aman/rnaseq_data/star_results/S55_Aligned.sortedByCoord.out.bam AuxinCPI
# /usr/users/papantonis1/aman/rnaseq_data/star_results/S56_Aligned.sortedByCoord.out.bam AuxinCPI
# /usr/users/papantonis1/aman/rnaseq_data/star_results/S57_Aligned.sortedByCoord.out.bam CPI
# /usr/users/papantonis1/aman/rnaseq_data/star_results/S58_Aligned.sortedByCoord.out.bam CPI
# /usr/users/papantonis1/aman/rnaseq_data/star_results/S59_Aligned.sortedByCoord.out.bam control
# /usr/users/papantonis1/aman/rnaseq_data/star_results/S60_Aligned.sortedByCoord.out.bam control

# %%
dds <- DESeqDataSetFromMatrix(countData = count_matrix,
                              colData = coldata,
                              design = ~ condition)

# design formula - gene expression based on the levels of the condition factor.

# %%
dds
# Out:
# class: DESeqDataSet
# dim: 86364 6
# metadata(1): version
# assays(1): counts
# rownames(86364): ENSG00000290825.2 ENSG00000223972.6 ...
#   ENSG00000297844.1 ENSG00000309258.1
# rowData names(0):
# colnames(6):
#   /usr/users/papantonis1/aman/rnaseq_data/star_results/S55_Aligned.sortedByCoord.out.bam
#   /usr/users/papantonis1/aman/rnaseq_data/star_results/S56_Aligned.sortedByCoord.out.bam
#   ...
#   /usr/users/papantonis1/aman/rnaseq_data/star_results/S59_Aligned.sortedByCoord.out.bam
#   /usr/users/papantonis1/aman/rnaseq_data/star_results/S60_Aligned.sortedByCoord.out.bam
# colData names(1): condition

# %%
#colnames(dds) <- c("S55", "S56", "S57", "S58", "S59", "S60")

# %%
dds$condition <- relevel(dds$condition, ref = "control")
# Setting the reference level of the factor condition in the dds object to "control"

# %%
#counts(dds)

# %%
levels(dds$condition)
# Out:
# [1] "control"  "CPI"      "AuxinCPI"

# %%
dds <- DESeq(dds, minReplicatesForReplace=Inf)
res <- results(dds, contrast = c("condition", "CPI", "control"), independentFiltering=FALSE, cooksCutoff=FALSE, alpha=0.15) # low filtering to retain canonical targets
res

# Fitting the negative binomial model and wald test for each gene comparing CPI vs control
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
# log2 fold change (MLE): condition CPI vs control
# Wald test p-value: condition CPI vs control
# DataFrame with 86364 rows and 6 columns
#                     baseMean log2FoldChange     lfcSE      stat    pvalue
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000290825.2   0.280936      -2.422587  4.904300 -0.493972  0.621326
# ENSG00000223972.6   0.000000             NA        NA        NA        NA
# ENSG00000310526.1 227.447545      -0.189165  0.321656 -0.588097  0.556467
# ENSG00000227232.6   0.000000             NA        NA        NA        NA
# ENSG00000278267.1   0.000000             NA        NA        NA        NA
# ...                      ...            ...       ...       ...       ...
# ENSG00000303867.1          0             NA        NA        NA        NA
# ENSG00000303902.1          0             NA        NA        NA        NA
# ENSG00000306528.1          0             NA        NA        NA        NA
# ENSG00000297844.1          0             NA        NA        NA        NA
# ENSG00000309258.1          0             NA        NA        NA        NA
#                        padj
#                   <numeric>
# ENSG00000290825.2         1
# ENSG00000223972.6        NA
# ENSG00000310526.1         1
# ENSG00000227232.6        NA
# ENSG00000278267.1        NA
# ...                     ...
# ENSG00000303867.1        NA
# ENSG00000303902.1        NA
# ENSG00000306528.1        NA
# ENSG00000297844.1        NA
# ENSG00000309258.1        NA

# %%
head(rownames(res), 20)
# Out:
#  [1] "ENSG00000290825.2" "ENSG00000223972.6" "ENSG00000310526.1"
#  [4] "ENSG00000227232.6" "ENSG00000278267.1" "ENSG00000243485.6"
#  [7] "ENSG00000284332.1" "ENSG00000237613.3" "ENSG00000308361.1"
# [10] "ENSG00000290826.2" "ENSG00000268020.3" "ENSG00000240361.3"
# [13] "ENSG00000186092.7" "ENSG00000241860.8" "ENSG00000239945.1"
# [16] "ENSG00000308314.1" "ENSG00000233750.3" "ENSG00000308579.1"
# [19] "ENSG00000268903.1" "ENSG00000269981.1"

# %%
res[c("ENSG00000105879.13", "ENSG00000106004.5", "ENSG00000179348.13"), c("pvalue", "padj", "log2FoldChange")]
# Out:
# log2 fold change (MLE): condition CPI vs control
# Wald test p-value: condition CPI vs control
# DataFrame with 3 rows and 3 columns
#                       pvalue      padj log2FoldChange
#                    <numeric> <numeric>      <numeric>
# ENSG00000105879.13 0.0599816   0.91855       0.240188
# ENSG00000106004.5  0.5544587   1.00000       0.106563
# ENSG00000179348.13 0.4998817   1.00000       0.135927

# %%
par(mar=c(8,5,2,2))
boxplot(log10(assays(dds)[["cooks"]]), range=0, las=2)
# Out:
# plot without title

# %%
summary(res, alpha=0.15)
# Out:
# out of 49321 with nonzero total read count
# adjusted p-value < 0.15
# LFC > 0 (up)       : 587, 1.2%
# LFC < 0 (down)     : 148, 0.3%
# outliers [1]       : 0, 0%
# low counts [2]     : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
## there are 49321 genes with non zero counts. 37k removed here

# %%
plotMA(res, ylim=c(-2,2))
# Out:
# Plot with title “”

# %%
plotCounts(dds, gene=which.max(res$log2FoldChange), intgroup="condition")
# Out:
# Plot with title “ENSG00000228205.1”

# %%
#write.csv(as.data.frame(resOrdered), 
#          file="condition_treated_results.csv")

# %%
plotDispEsts(dds)
# Out:
# plot without title

# %% [markdown]
# ### Transform - VST main

# %%
vsd <- vst(dds, blind=FALSE)
head(assay(vsd), 3)
# Out:
#                   /usr/users/papantonis1/aman/rnaseq_data/star_results/S55_Aligned.sortedByCoord.out.bam
# ENSG00000290825.2 8.763552
# ENSG00000223972.6 8.763552
# ENSG00000310526.1 9.192389
#                   /usr/users/papantonis1/aman/rnaseq_data/star_results/S56_Aligned.sortedByCoord.out.bam
# ENSG00000290825.2 8.763552
# ENSG00000223972.6 8.763552
# ENSG00000310526.1 9.358516
#                   /usr/users/papantonis1/aman/rnaseq_data/star_results/S57_Aligned.sortedByCoord.out.bam
# ENSG00000290825.2 8.763552
# ENSG00000223972.6 8.763552
# ENSG00000310526.1 9.942039
#                   /usr/users/papantonis1/aman/rnaseq_data/star_results/S58_Aligned.sortedByCoord.out.bam
# ENSG00000290825.2 8.763552
# ENSG00000223972.6 8.763552
# ENSG00000310526.1 9.888528
#                   /usr/users/papantonis1/aman/rnaseq_data/star_results/S59_Aligned.sortedByCoord.out.bam
# ENSG00000290825.2 8.853386
# ENSG00000223972.6 8.763552
# ENSG00000310526.1 9.948701
#                   /usr/users/papantonis1/aman/rnaseq_data/star_results/S60_Aligned.sortedByCoord.out.bam
# ENSG00000290825.2  8.763552
# ENSG00000223972.6  8.763552
# ENSG00000310526.1 10.029176

# %%
library("vsn")
meanSdPlot(assay(vsd))
# Out:
# plot without title

# %% [markdown]
# ### NormTransform

# %%
ntd <- normTransform(dds)
meanSdPlot(assay(ntd))
# Out:
# plot without title

# %%
library("pheatmap")

select <- order(rowMeans(counts(dds, normalized=TRUE)), decreasing=TRUE)[1:20]


# Reassign colnames and ensure annotation matches order
colnames(vsd) <- c("S55", "S56", "S57", "S58", "S59", "S60")
df <- as.data.frame(colData(dds)[, "condition", drop = FALSE])
rownames(df) <- colnames(vsd)
df$condition <- factor(df$condition, levels = c("control", "CPI", "AuxinCPI"))



# Define annotation colors
ann_colors <- list(
  condition = c("control" = "#56B4E9", "CPI" = "#D55E00", "AuxinCPI" = "#009E73")
)

pheatmap(
  assay(ntd)[select, ],
  cluster_rows = TRUE,
  show_rownames = FALSE,
  cluster_cols = TRUE,
  annotation_col = df,
  annotation_colors = ann_colors
)
# Out:
# plot without title

# %%
all(colnames(assay(vsd)) == rownames(df))
# Out:
# [1] TRUE

# %%
colnames(vsd) <- c("S55", "S56", "S57", "S58", "S59", "S60")
pheatmap(
  assay(vsd)[select, ],
  cluster_rows = TRUE,
  show_rownames = TRUE,
  cluster_cols = TRUE,
  annotation_col = df,
  annotation_colors = ann_colors
)
# Out:
# plot without title

# %%
sampleDists <- dist(t(assay(vsd)))
library("RColorBrewer")
sampleDistMatrix <- as.matrix(sampleDists)
rownames(sampleDistMatrix) <- paste(vsd$condition, vsd$type, sep="-")
colnames(sampleDistMatrix) <- NULL
colors <- colorRampPalette( rev(brewer.pal(9, "Blues")) )(255)
pheatmap(sampleDistMatrix,
         clustering_distance_rows=sampleDists,
         clustering_distance_cols=sampleDists,
         col=colors)

# control and cpi correlated which in a way makes sense biologically
# Out:
# plot without title

# %%
plotPCA(vsd, intgroup=c("condition"))
# Out:
# using ntop=500 top features by variance
# plot without title

# %%
#options(repr.plot.width = 8, repr.plot.height = 9)
#plotPCA(vsd, intgroup = "condition") + theme(aspect.ratio = 1.5)
pca <- prcomp(t(assay(vsd)))
summary(pca)
# Out:
# Importance of components:
#                            PC1      PC2     PC3     PC4     PC5      PC6
# Standard deviation     45.4993 10.57308 7.46943 5.94246 5.55822 1.41e-13
# Proportion of Variance  0.8985  0.04852 0.02422 0.01533 0.01341 0.00e+00
# Cumulative Proportion   0.8985  0.94705 0.97126 0.98659 1.00000 1.00e+00

# %% [markdown]
# ### Log fold change shrinkage

# %%
resultsNames(dds)
# Out:
# [1] "Intercept"                     "condition_CPI_vs_control"
# [3] "condition_AuxinCPI_vs_control"

# %%
resLFC <- lfcShrink(dds, coef="condition_CPI_vs_control", type="apeglm")
resLFC
# Out:
# using 'apeglm' for LFC shrinkage. If used in published research, please cite:
#     Zhu, A., Ibrahim, J.G., Love, M.I. (2018) Heavy-tailed prior distributions for
#     sequence count data: removing the noise and preserving large differences.
#     Bioinformatics. https://doi.org/10.1093/bioinformatics/bty895
# log2 fold change (MAP): condition CPI vs control
# Wald test p-value: condition CPI vs control
# DataFrame with 86364 rows and 5 columns
#                     baseMean log2FoldChange     lfcSE    pvalue      padj
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000290825.2   0.280936    -0.00182447  0.126213  0.621326        NA
# ENSG00000223972.6   0.000000             NA        NA        NA        NA
# ENSG00000310526.1 227.447545    -0.02542982  0.120621  0.556467  0.806729
# ENSG00000227232.6   0.000000             NA        NA        NA        NA
# ENSG00000278267.1   0.000000             NA        NA        NA        NA
# ...                      ...            ...       ...       ...       ...
# ENSG00000303867.1          0             NA        NA        NA        NA
# ENSG00000303902.1          0             NA        NA        NA        NA
# ENSG00000306528.1          0             NA        NA        NA        NA
# ENSG00000297844.1          0             NA        NA        NA        NA
# ENSG00000309258.1          0             NA        NA        NA        NA

# %%
# order based on the pval
resOrdered <- res[order(res$pvalue),]
resOrdered
# Out:
# log2 fold change (MLE): condition CPI vs control
# Wald test p-value: condition CPI vs control
# DataFrame with 86364 rows and 6 columns
#                     baseMean log2FoldChange     lfcSE      stat      pvalue
#                    <numeric>      <numeric> <numeric> <numeric>   <numeric>
# ENSG00000170385.10   8457.71       1.003893  0.114580   8.76151 1.92644e-18
# ENSG00000100600.15   4123.34       0.913378  0.140299   6.51021 7.50440e-11
# ENSG00000104805.17   3677.86       0.926150  0.145961   6.34520 2.22138e-10
# ENSG00000169116.11  10740.23       0.715329  0.113664   6.29336 3.10658e-10
# ENSG00000067141.17   2414.47       0.912804  0.152194   5.99763 2.00223e-09
# ...                      ...            ...       ...       ...         ...
# ENSG00000303867.1          0             NA        NA        NA          NA
# ENSG00000303902.1          0             NA        NA        NA          NA
# ENSG00000306528.1          0             NA        NA        NA          NA
# ENSG00000297844.1          0             NA        NA        NA          NA
# ENSG00000309258.1          0             NA        NA        NA          NA
#                           padj
#                      <numeric>
# ENSG00000170385.10 9.50139e-14
# ENSG00000100600.15 1.85062e-06
# ENSG00000104805.17 3.65202e-06
# ENSG00000169116.11 3.83049e-06
# ENSG00000067141.17 1.97504e-05
# ...                        ...
# ENSG00000303867.1           NA
# ENSG00000303902.1           NA
# ENSG00000306528.1           NA
# ENSG00000297844.1           NA
# ENSG00000309258.1           NA

# %%
# filtering with padj < 0.05
sum(res$padj < 0.05, na.rm=TRUE)
# Out:
# [1] 362

# %%
res_raw <- results(dds, contrast = c("condition", "CPI", "control"))

# %%
plotMA(res_raw, ylim=c(-2,2), main="normal - no shrinking")
# Out:
# Plot with title “normal - no shrinking”

# %%
plotMA(resLFC, ylim=c(-2,2), main="apeglm")
# Out:
# Plot with title “apeglm”

# %%
mcols(res)$description
# Out:
# [1] "mean of normalized counts for all samples"
# [2] "log2 fold change (MLE): condition CPI vs control"
# [3] "standard error: condition CPI vs control"
# [4] "Wald statistic: condition CPI vs control"
# [5] "Wald test p-value: condition CPI vs control"
# [6] "BH adjusted p-values"

# %%
sig_res <- res[which(res$padj < 0.1), ]

# %%
sig_res
# Out:
# log2 fold change (MLE): condition CPI vs control
# Wald test p-value: condition CPI vs control
# DataFrame with 575 rows and 6 columns
#                     baseMean log2FoldChange     lfcSE      stat      pvalue
#                    <numeric>      <numeric> <numeric> <numeric>   <numeric>
# ENSG00000187961.15   637.683      -0.803631 0.2106553  -3.81491 1.36232e-04
# ENSG00000131584.19  2362.876      -0.809808 0.1619122  -5.00152 5.68792e-07
# ENSG00000107404.21  3137.363      -0.504762 0.1277532  -3.95107 7.78017e-05
# ENSG00000221978.13 15586.896      -0.318604 0.0864294  -3.68629 2.27550e-04
# ENSG00000197530.13  1819.242      -0.630652 0.1533390  -4.11280 3.90892e-05
# ...                      ...            ...       ...       ...         ...
# ENSG00000147100.11   435.368       0.748524  0.221859   3.37387 7.41192e-04
# ENSG00000005893.17 10894.908       0.439498  0.110259   3.98605 6.71834e-05
# ENSG00000147383.11  1603.104       0.668064  0.172772   3.86674 1.10301e-04
# ENSG00000147394.20  1327.598       0.709374  0.175302   4.04659 5.19695e-05
# ENSG00000071553.18  5928.334       0.468645  0.126512   3.70435 2.11935e-04
#                           padj
#                      <numeric>
# ENSG00000187961.15 0.026144292
# ENSG00000131584.19 0.000935113
# ENSG00000107404.21 0.017625293
# ENSG00000221978.13 0.036320315
# ENSG00000197530.13 0.011475718
# ...                        ...
# ENSG00000147100.11   0.0769446
# ENSG00000005893.17   0.0162429
# ENSG00000147383.11   0.0227100
# ENSG00000147394.20   0.0137113
# ENSG00000071553.18   0.0349645

# %%
upregulated <- sig_res[which(sig_res$log2FoldChange > 0.6), ]
up_genes <- rownames(upregulated)

# %%
downregulated <- sig_res[which(sig_res$log2FoldChange < - 0.6), ]
down_genes <- rownames(downregulated)

# %%
length(up_genes)
# Out:
# [1] 164

# %%
length(down_genes)
# Out:
# [1] 58

# %%
setwd("/usr/users/papantonis1/aman/rnaseq_data")

# %%
#write.table(up_genes, file="upregulated_genes.txt", quote=FALSE, row.names=FALSE, col.names=FALSE)
#write.table(down_genes, file="downregulated_genes.txt", quote=FALSE, row.names=FALSE, col.names=FALSE)

# %%
up_df <- data.frame(
  ensembl = rownames(upregulated),
  log2FC = upregulated$log2FoldChange
)

write.table(up_df, file = "upregulated_genes.txt", sep = "\t", quote = FALSE, row.names = FALSE)

# %%
down_df <- data.frame(
  ensembl = rownames(downregulated),
  log2FC = downregulated$log2FoldChange
)
write.table(down_df, file = "downregulated_genes.txt", sep = "\t", quote = FALSE, row.names = FALSE)

# %%
# Full result from DESeq2, no filtering by padj
gene_df <- data.frame(
  ensembl = rownames(res),
  log2FC = res$log2FoldChange
)

# Optional: remove NA
gene_df <- na.omit(gene_df)

# Write full ranked gene list for GSEA
write.table(gene_df, file = "ranked_gene_list.txt", sep = "\t", quote = FALSE, row.names = FALSE)

gene_df
# Out:
#       ensembl            log2FC
# 1     ENSG00000290825.2  -2.42258691
# 3     ENSG00000310526.1  -0.18916477
# 6     ENSG00000243485.6  -1.25585264
# 9     ENSG00000308361.1   0.00000000
# 14    ENSG00000241860.8  -0.16632248
# 18    ENSG00000308579.1  -1.95519125
# 19 ENSG00000200959.1  -1.0556500
# 20 ENSG00000164877.19 -0.6006837
# 21 ENSG00000175305.18 -0.7293798
# 22 ENSG00000179698.14 -1.0540200
# 23 ENSG00000167702.13 -0.8285275
# 24 ENSG00000160972.10 -0.6620177
# 25 ENSG00000198467.16 -1.5445773
# 26 ENSG00000177943.14 -0.7343841
# 27 ENSG00000148377.6  -5.5664633
# 28 ENSG00000255026.2  -1.0689149
# 29 ENSG00000142102.16 -0.7753631
# 30 ENSG00000177685.17 -0.7038128
# 31 ENSG00000149043.17 -0.9639652
# 32 ENSG00000130598.17 -1.1202929
# 33 ENSG00000255717.10 -0.6188405
# 34 ENSG00000287666.2  -5.1159733
# 35 ENSG00000257378.1  -5.6047930
# 36 ENSG00000111554.15 -0.6692859
# 37 ENSG00000212443.1  -0.6930604
# 38 ENSG00000208892.1  -0.9462687
# 39 ENSG00000258498.11 -1.2444872
# 40 ENSG00000175265.19 -0.6163952
# 41 ENSG00000185634.12 -3.1272276
# 42 ENSG00000161996.19 -0.7423133
# 43 ENSG00000103269.14 -1.0960115
# 44 ENSG00000197774.14 -0.7582793
# 45 ENSG00000167968.13 -0.8425943
# 46 ENSG00000245694.13 -0.7264556
# 47 ENSG00000185324.22 -0.6244567
# 48 ENSG00000262074.7  -0.7974996
# 49 ENSG00000263934.5  -0.7597004
# 50 ENSG00000264940.5  -0.9669695
# 51 ENSG00000291117.2  -0.6581974
# 52 ENSG00000169683.8  -1.0757249
# 53 ENSG00000105173.14 -0.8496167
# 54 ENSG00000133247.14 -0.7660030
# 55 ENSG00000026036.23 -0.9577087
# 56 ENSG00000101246.20 -0.6434456
# 57 ENSG00000304313.1  -2.5449062
# 58 ENSG00000168135.4  -5.7567376

# %%
library(EnhancedVolcano)
EnhancedVolcano(resLFC,
  lab = rownames(resLFC),
  x = 'log2FoldChange',
  y = 'padj',
  pCutoff = 0.1,
  FCcutoff = 0.6)

# resLFC used as it is the shrunk one
# Out:
# Loading required package: ggplot2
# Loading required package: ggrepel
# plot without title

# %% [markdown]
# ### The next step is to display the gene names instead of the ensembl ids

# %%
# todo

# %%
# Skip 'version="devel"' which pulls the latest (3.22, needs R 4.5)
#BiocManager::install(version = "3.18")
#BiocManager::install("biomaRt")

# %%
library(biomaRt)

# %%
# Set up biomart
mart <- useEnsembl(biomart = "genes", dataset = "hsapiens_gene_ensembl")

# Remove version suffix (.10, .11 etc.)
ids <- gsub("\\..*", "", rownames(resLFC))

# Query gene names
annot <- getBM(
  attributes = c("ensembl_gene_id", "hgnc_symbol"),
  filters = "ensembl_gene_id",
  values = ids,
  mart = mart
)

# %%
annot
# Out:
#       ensembl_gene_id hgnc_symbol
# 1     ENSG00000000938 FGR
# 2     ENSG00000001460 STPG1
# 3     ENSG00000001461 NIPAL3
# 4     ENSG00000004455 AK2
# 5     ENSG00000004487 KDM1A
# 6     ENSG00000006555 TTC22
# 7     ENSG00000007341 ST7L
# 8     ENSG00000007923 DNAJC11
# 9     ENSG00000007968 E2F2
# 10    ENSG00000008128 CDK11A
# 11    ENSG00000008130 NADK
# 12    ENSG00000009307 CSDE1
# 13    ENSG00000009709 PAX7
# 14    ENSG00000009724 MASP2
# 15    ENSG00000009780 FAM76A
# 16    ENSG00000010803 SCMH1
# 17    ENSG00000011007 ELOA
# 18    ENSG00000011009 LYPLA2
# 19    ENSG00000011021 CLCN6
# 20    ENSG00000014914 MTMR11
# 21    ENSG00000016490 CLCA1
# 22    ENSG00000016602 CLCA4
# 23    ENSG00000018625 ATP1A2
# 24    ENSG00000020129 NCDN
# 25    ENSG00000020633 RUNX3
# 26    ENSG00000021852 C8B
# 27    ENSG00000023902 PLEKHO1
# 28    ENSG00000023909 GCLM
# 29    ENSG00000024526 DEPDC1
# 30    ENSG00000025800 KPNA6
# ⋮     ⋮               ⋮
# 86339 ENSG00000307249
# 86340 ENSG00000307470
# 86341 ENSG00000307608
# 86342 ENSG00000307722
# 86343 ENSG00000307824
# 86344 ENSG00000308185
# 86345 ENSG00000308567
# 86346 ENSG00000308580
# 86347 ENSG00000308643
# 86348 ENSG00000308844
# 86349 ENSG00000308964
# 86350 ENSG00000308966
# 86351 ENSG00000309079
# 86352 ENSG00000309229
# 86353 ENSG00000309233
# 86354 ENSG00000309258
# 86355 ENSG00000309296
# 86356 ENSG00000309335
# 86357 ENSG00000309338
# 86358 ENSG00000309357
# 86359 ENSG00000309787
# 86360 ENSG00000309793
# 86361 ENSG00000309802
# 86362 ENSG00000309831
# 86363 ENSG00000310156
# 86364 ENSG00000310277
# 86365 ENSG00000310347
# 86366 ENSG00000310376
# 86367 ENSG00000310392
# 86368 ENSG00000310401

# %%
# Merge with result table
resLFC$ensembl_id <- gsub("\\..*", "", rownames(resLFC))
res_annot <- merge(as.data.frame(resLFC), annot, by.x = "ensembl_id", by.y = "ensembl_gene_id", all.x = TRUE)

# Set gene symbols as rownames (fallback to Ensembl if missing)
res_annot$label <- ifelse(res_annot$hgnc_symbol == "", res_annot$ensembl_id, res_annot$hgnc_symbol)

# %%
EnhancedVolcano(
  res_annot,
  lab = res_annot$label,
  x = 'log2FoldChange',
  y = 'padj',
  pCutoff = 0.1,
  FCcutoff = 0.6
)
# Out:
# plot without title

# %%
head(up_df)
# Out:
#   ensembl            log2FC
# 1 ENSG00000171603.18 0.6236341
# 2 ENSG00000083444.17 0.6531234
# 3 ENSG00000117298.16 0.7427075
# 4 ENSG00000133216.17 0.8813826
# 5 ENSG00000090020.11 0.7566302
# 6 ENSG00000204138.13 0.6088367

# %%
head(down_df)
# Out:
#   ensembl            log2FC
# 1 ENSG00000187961.15 -0.8036312
# 2 ENSG00000131584.19 -0.8098075
# 3 ENSG00000197530.13 -0.6306522
# 4 ENSG00000158286.13 -0.7327465
# 5 ENSG00000142733.18 -0.7232720
# 6 ENSG00000274210.1  -0.9842403

# %%
# Load biomaRt
library(biomaRt)

# Strip version suffixes
up_df$ensembl_id <- sub("\\..*", "", up_df$ensembl)
down_df$ensembl_id <- sub("\\..*", "", down_df$ensembl)

# Connect to Ensembl
mart <- useEnsembl(biomart = "genes", dataset = "hsapiens_gene_ensembl")

# Get gene symbols
gene_info <- getBM(
  attributes = c("ensembl_gene_id", "hgnc_symbol"),
  filters = "ensembl_gene_id",
  values = unique(c(up_df$ensembl_id, down_df$ensembl_id)),
  mart = mart
)

# Merge gene symbols with up_df
up_df_annot <- merge(up_df, gene_info, by.x = "ensembl_id", by.y = "ensembl_gene_id", all.x = TRUE)

# Merge gene symbols with down_df
down_df_annot <- merge(down_df, gene_info, by.x = "ensembl_id", by.y = "ensembl_gene_id", all.x = TRUE)

# %%
# Replace missing hgnc_symbol with ensembl_id
up_df_annot$hgnc_symbol <- ifelse(
  up_df_annot$hgnc_symbol == "" | is.na(up_df_annot$hgnc_symbol),
  up_df_annot$ensembl_id,
  up_df_annot$hgnc_symbol
)

down_df_annot$hgnc_symbol <- ifelse(
  down_df_annot$hgnc_symbol == "" | is.na(down_df_annot$hgnc_symbol),
  down_df_annot$ensembl_id,
  down_df_annot$hgnc_symbol
)

# %%
up_df_annot
# Out:
#     ensembl_id      ensembl            log2FC    hgnc_symbol
# 1   ENSG00000005339 ENSG00000005339.15 0.6531038 CREBBP
# 2   ENSG00000011347 ENSG00000011347.10 0.6965520 SYT7
# 3   ENSG00000013288 ENSG00000013288.9  0.7036436 MAN2B2
# 4   ENSG00000026508 ENSG00000026508.21 0.7497931 CD44
# 5   ENSG00000030582 ENSG00000030582.19 0.9126872 GRN
# 6   ENSG00000041982 ENSG00000041982.17 0.6878423 TNC
# 7   ENSG00000047662 ENSG00000047662.5  1.3618516 FAM184B
# 8   ENSG00000048740 ENSG00000048740.19 1.5979083 CELF2
# 9   ENSG00000049323 ENSG00000049323.16 0.6825615 LTBP1
# 10  ENSG00000058085 ENSG00000058085.15 0.6441626 LAMC2
# 11  ENSG00000062038 ENSG00000062038.15 0.6159610 CDH3
# 12  ENSG00000065989 ENSG00000065989.16 1.5949708 PDE4A
# 13  ENSG00000067141 ENSG00000067141.17 0.9128043 NEO1
# 14  ENSG00000068489 ENSG00000068489.13 0.7475017 PRR11
# 15  ENSG00000075218 ENSG00000075218.19 0.7568180 GTSE1
# 16  ENSG00000078081 ENSG00000078081.8  0.7036510 LAMP3
# 17  ENSG00000079156 ENSG00000079156.17 1.7887096 OSBPL6
# 18  ENSG00000083444 ENSG00000083444.17 0.6531234 PLOD1
# 19  ENSG00000084234 ENSG00000084234.18 0.6172973 APLP2
# 20  ENSG00000085872 ENSG00000085872.15 0.7415358 CHERP
# 21  ENSG00000088038 ENSG00000088038.20 0.8635725 CNOT3
# 22  ENSG00000088325 ENSG00000088325.16 0.6166898 TPX2
# 23  ENSG00000089597 ENSG00000089597.18 0.7338429 GANAB
# 24  ENSG00000090020 ENSG00000090020.11 0.7566302 SLC9A1
# 25  ENSG00000092621 ENSG00000092621.13 0.7583655 PHGDH
# 26  ENSG00000096746 ENSG00000096746.18 0.6945621 HNRNPH3
# 27  ENSG00000099194 ENSG00000099194.6  0.6469181 SCD
# 28  ENSG00000099797 ENSG00000099797.15 0.6652468 TECR
# 29  ENSG00000099995 ENSG00000099995.19 0.6615761 SF3A1
# 50 ENSG00000258498 ENSG00000258498.11 -1.2444872 DIO3OS
# 51 ENSG00000262074 ENSG00000262074.7  -0.7974996 SNORD3B-2
# 52 ENSG00000263934 ENSG00000263934.5  -0.7597004 SNORD3A
# 53 ENSG00000264940 ENSG00000264940.5  -0.9669695 SNORD3C
# 54 ENSG00000274210 ENSG00000274210.1  -0.9842403 RNVU1-27
# 55 ENSG00000287666 ENSG00000287666.2  -5.1159733 ENSG00000287666
# 56 ENSG00000291117 ENSG00000291117.2  -0.6581974 ENSG00000291117
# 57 ENSG00000304313 ENSG00000304313.1  -2.5449062 ENSG00000304313
# 58 ENSG00000307581 ENSG00000307581.1  -1.6777565 ENSG00000307581

# %%
write.table(up_df_annot, file = "upregulated_genes_deseq.txt", sep = "\t", quote = FALSE, row.names = FALSE)
write.table(down_df_annot, file = "downregulated_genes_deseq.txt", sep = "\t", quote = FALSE, row.names = FALSE)

# %%
library(biomaRt)
library(clusterProfiler)
library(org.Hs.eg.db)
library(readr)
run_go_enrichment_from_file <- function(filepath, delim = "\t", symbol_col = "hgnc_symbol") {
  # Load gene list
  genes_df <- read_delim(filepath, delim = delim, show_col_types = FALSE)
  
  # Extract and standardize gene symbols
  symbols <- toupper(genes_df[[symbol_col]])
  
  # Map to Entrez IDs using BioMart
  mart <- useEnsembl(biomart = "genes", dataset = "hsapiens_gene_ensembl")
  converted <- getBM(
    filters = "hgnc_symbol",
    attributes = c("hgnc_symbol", "entrezgene_id"),
    values = symbols,
    mart = mart
  )
  converted <- na.omit(converted)

  # Perform GO enrichment if mappings exist
  if (nrow(converted) == 0) {
    message("No valid gene symbols could be mapped to Entrez IDs.")
    return(NULL)
  }

  ego <- enrichGO(
    gene          = converted$entrezgene_id,
    OrgDb         = org.Hs.eg.db,
    ont           = "BP",
    pAdjustMethod = "BH",
    pvalueCutoff  = 0.1,
    readable      = TRUE
  )

  return(ego)
}
# Out:
# clusterProfiler v4.10.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:biomaRt’:
#
#     select
#
#
# The following object is masked from ‘package:IRanges’:
#
#     slice
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     rename
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# Loading required package: AnnotationDbi
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
#
#
# Warning message:
# “package ‘readr’ was built under R version 4.4.3”

# %%
ego_result_up_deseq <- run_go_enrichment_from_file("/usr/users/papantonis1/aman/rnaseq_data/upregulated_genes_deseq.txt")

# View results
as.data.frame(ego_result_up_deseq)
# Out:
#            ID
# GO:0021782 GO:0021782
# GO:0042063 GO:0042063
# GO:0010001 GO:0010001
# GO:0048143 GO:0048143
# GO:0001774 GO:0001774
# GO:0002269 GO:0002269
# GO:0031103 GO:0031103
# GO:0010800 GO:0010800
# GO:0061900 GO:0061900
# GO:0031102 GO:0031102
# GO:1900182 GO:1900182
# GO:0050808 GO:0050808
# GO:1900180 GO:1900180
# GO:0007612 GO:0007612
# GO:0018210 GO:0018210
# GO:0030214 GO:0030214
# GO:0090307 GO:0090307
# GO:0046718 GO:0046718
# GO:0019058 GO:0019058
# GO:0042307 GO:0042307
# GO:0043112 GO:0043112
# GO:1905906 GO:1905906
# GO:0003018 GO:0003018
# GO:0048167 GO:0048167
# GO:0044409 GO:0044409
# GO:0042267 GO:0042267
# GO:0007611 GO:0007611
# GO:0042063 12
# GO:0010001 10
# GO:0048143  4
# GO:0001774  5
# GO:0002269  5
# GO:0031103  5
# GO:0010800  4
# GO:0061900  5
# GO:0031102  5
# GO:1900182  6
# GO:0050808 13
# GO:1900180  7
# GO:0007612  7
# GO:0018210  6
# GO:0030214  3
# GO:0090307  5
# GO:0046718  7
# GO:0019058 10
# GO:0042307  4
# GO:0043112  5
# GO:1905906  3
# GO:0003018  9
# GO:0048167  8
# GO:0044409  7
# GO:0042267  5
# GO:0007611  9
# GO:0007088  6
# GO:0150079  3
# GO:1901970  3
# ⋮          ⋮
# GO:0045687 3
# GO:0033674 8
# GO:0030071 4
# GO:0032768 3
# GO:0085029 3
# GO:1900271 3
# GO:1901976 3
# GO:0030111 8
# GO:0106027 4
# GO:0061684 2
# GO:2001028 2
# GO:0001881 3
# GO:0032869 6
# GO:1903510 4
# GO:0030177 5
# GO:0032465 4
# GO:1902099 4
# GO:0021795 3
# GO:0018108 7
# GO:0007091 4
# GO:2001251 4
# GO:0008608 3
# GO:0031648 3
# GO:0042269 3
# GO:0002486 2
# GO:0032926 2
# GO:0032930 2
# GO:0048712 2
# GO:0018212 7
# GO:0045862 8

# %%
dotplot(ego_result_up_deseq, showCategory = 20, title = "GO Enrichment (upregulated genes deseq)")
barplot(ego_result_up_deseq, showCategory = 20, title = "GO Enrichment (upregulated genes deseq)")
# Out:
# plot without title
# plot without title

# %%
library(biomaRt)
library(clusterProfiler)
library(org.Hs.eg.db)
library(readr)
run_go_enrichment_from_file <- function(filepath, delim = "\t", symbol_col = "hgnc_symbol") {
  # Load gene list
  genes_df <- read_delim(filepath, delim = delim, show_col_types = FALSE)
  
  # Extract and standardize gene symbols
  symbols <- toupper(genes_df[[symbol_col]])
  
  # Map to Entrez IDs using BioMart
  mart <- useEnsembl(biomart = "genes", dataset = "hsapiens_gene_ensembl")
  converted <- getBM(
    filters = "hgnc_symbol",
    attributes = c("hgnc_symbol", "entrezgene_id"),
    values = symbols,
    mart = mart
  )
  converted <- na.omit(converted)

  # Perform GO enrichment if mappings exist
  if (nrow(converted) == 0) {
    message("No valid gene symbols could be mapped to Entrez IDs.")
    return(NULL)
  }

  ego <- enrichGO(
    gene          = converted$entrezgene_id,
    OrgDb         = org.Hs.eg.db,
    ont           = "BP",
    pAdjustMethod = "BH",
    pvalueCutoff  = 0.2,
    readable      = TRUE
  )

  return(ego)
}

# %%
ego_result_down_deseq <- run_go_enrichment_from_file("/usr/users/papantonis1/aman/rnaseq_data/downregulated_genes_deseq.txt")

# View results
as.data.frame(ego_result_down_deseq)
# Out:
#            ID         Description                  GeneRatio BgRatio
# GO:0007127 GO:0007127 meiosis I                    4/38      129/18870
# GO:0061982 GO:0061982 meiosis I cell cycle process 4/38      136/18870
# GO:0140013 GO:0140013 meiotic nuclear division     4/38      194/18870
# GO:1903046 GO:1903046 meiotic cell cycle process   4/38      214/18870
#            pvalue       p.adjust   qvalue     geneID                Count
# GO:0007127 0.0001285074 0.05049348 0.04709795 CCNE1/CCNE2/EME2/ING2 4
# GO:0061982 0.0001575460 0.05049348 0.04709795 CCNE1/CCNE2/EME2/ING2 4
# GO:0140013 0.0006081859 0.12994905 0.12121038 CCNE1/CCNE2/EME2/ING2 4
# GO:1903046 0.0008775458 0.14062671 0.13117000 CCNE1/CCNE2/EME2/ING2 4

# %%
dotplot(ego_result_down_deseq, showCategory = 20, title = "GO Enrichment (downregulated genes deseq)")
barplot(ego_result_down_deseq, showCategory = 20, title = "GO Enrichment (downregulated genes deseq)")
# Out:
# plot without title
# plot without title

# %%
# testing enrichr

# %%
c2 <- read.gmt("/usr/users/papantonis1/aman/rnaseq_data/c2.all.v2025.1.Hs.symbols.gmt")
enrich_res <- enricher(up_df_annot$hgnc_symbol, TERM2GENE = c2)

# %%
enrich_res
# Out:
# #
# # over-representation test
# #
# #...@organism 	 UNKNOWN
# #...@ontology 	 UNKNOWN
# #...@gene 	 chr [1:164] "CREBBP" "SYT7" "MAN2B2" "CD44" "GRN" "TNC" "FAM184B" "CELF2" ...
# #...pvalues adjusted by 'BH' with cutoff <0.05
# #...439 enriched terms found
# 'data.frame':	439 obs. of  9 variables:
#  $ ID         : chr  "MILI_PSEUDOPODIA_CHEMOTAXIS_DN" "DEBIASI_APOPTOSIS_BY_REOVIRUS_INFECTION_DN" "JOHNSTONE_PARVB_TARGETS_3_UP" "REN_ALVEOLAR_RHABDOMYOSARCOMA_DN" ...
#  $ Description: chr  "MILI_PSEUDOPODIA_CHEMOTAXIS_DN" "DEBIASI_APOPTOSIS_BY_REOVIRUS_INFECTION_DN" "JOHNSTONE_PARVB_TARGETS_3_UP" "REN_ALVEOLAR_RHABDOMYOSARCOMA_DN" ...
#  $ GeneRatio  : chr  "22/162" "18/162" "21/162" "19/162" ...
#  $ BgRatio    : chr  "429/22381" "276/22381" "433/22381" "407/22381" ...
#  $ pvalue     : num  6.68e-13 1.77e-12 6.69e-12 1.38e-10 1.96e-10 ...
#  $ p.adjust   : num  2.06e-09 2.73e-09 6.88e-09 1.06e-07 1.21e-07 ...
#  $ qvalue     : num  1.50e-09 1.98e-09 4.99e-09 7.72e-08 8.77e-08 ...
#  $ geneID     : chr  "GRN/PLOD1/APLP2/CNOT3/GANAB/SCD/SUN2/LGMN/QSOX1/SCPEP1/POR/LDLR/CKAP4/APP/FAM171A1/PCDH1/GAA/CLSTN1/DAG1/PSAP/PPP1R10/HLA-B" "NOMO1/SLC1A5/PTK7/POR/PODXL/EPHB2/RNFT2/SERPINE2/MKI67/HYOU1/PDIA4/PRKCD/CLSTN1/DAG1/MAGED1/SEPTIN9/TMT1A/HEXIM1" "GRN/APLP2/SCD/LGMN/SRPX/LGALS3BP/ECE1/TGFBI/CLU/LDLR/BHLHE40/CDCP1/C15orf39/SLC30A1/GAA/DAG1/JUP/SEZ6L2/SEPTIN9/PSAP/HLA-B" "MAN2B2/GRN/PLOD1/APLP2/XYLT1/CEMIP/NUCB1/TGFB1/LGALS3BP/QSOX1/CCN2/TGFBI/CLU/SCPEP1/SERPINE2/EPHX1/EGFR/BAG3/SMTN" ...
#  $ Count      : int  22 18 21 19 15 15 19 12 9 17 ...
# #...Citation
#  T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu.
#  clusterProfiler 4.0: A universal enrichment tool for interpreting omics data.
#  The Innovation. 2021, 2(3):100141

# %%
dotplot(enrich_res)
# Out:
# plot without title

# %%
# Show all significant Polycomb-related sets
subset(enrich_res@result, grepl("PRC2|POLYCOMB|H3K27|EZH2|SUZ12", Description, ignore.case = TRUE))
# Out:
#                                             ID
# LU_EZH2_TARGETS_DN                          LU_EZH2_TARGETS_DN
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN       ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN
# KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3     KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3
# LU_EZH2_TARGETS_UP                          LU_EZH2_TARGETS_UP
# PASINI_SUZ12_TARGETS_DN                     PASINI_SUZ12_TARGETS_DN
# PASINI_SUZ12_TARGETS_UP                     PASINI_SUZ12_TARGETS_UP
# MIKKELSEN_MCV6_HCP_WITH_H3K27ME3            MIKKELSEN_MCV6_HCP_WITH_H3K27ME3
# KONDO_EZH2_TARGETS                          KONDO_EZH2_TARGETS
# MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3  MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3
# KAMMINGA_EZH2_TARGETS                       KAMMINGA_EZH2_TARGETS
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3  MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# MEISSNER_NPC_HCP_WITH_H3K27ME3              MEISSNER_NPC_HCP_WITH_H3K27ME3
# MIKKELSEN_NPC_HCP_WITH_H3K27ME3             MIKKELSEN_NPC_HCP_WITH_H3K27ME3
# MEISSNER_BRAIN_HCP_WITH_H3K27ME3            MEISSNER_BRAIN_HCP_WITH_H3K27ME3
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP       ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3  MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
# MIKKELSEN_MEF_ICP_WITH_H3K27ME3             MIKKELSEN_MEF_ICP_WITH_H3K27ME3
# MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3 MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
#                                             Description
# LU_EZH2_TARGETS_DN                          LU_EZH2_TARGETS_DN
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN       ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN
# KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3     KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3
# LU_EZH2_TARGETS_UP                          LU_EZH2_TARGETS_UP
# PASINI_SUZ12_TARGETS_DN                     PASINI_SUZ12_TARGETS_DN
# PASINI_SUZ12_TARGETS_UP                     PASINI_SUZ12_TARGETS_UP
# MIKKELSEN_MCV6_HCP_WITH_H3K27ME3            MIKKELSEN_MCV6_HCP_WITH_H3K27ME3
# KONDO_EZH2_TARGETS                          KONDO_EZH2_TARGETS
# MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3  MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3
# KAMMINGA_EZH2_TARGETS                       KAMMINGA_EZH2_TARGETS
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3  MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3
# MEISSNER_NPC_HCP_WITH_H3K27ME3              MEISSNER_NPC_HCP_WITH_H3K27ME3
# MIKKELSEN_NPC_HCP_WITH_H3K27ME3             MIKKELSEN_NPC_HCP_WITH_H3K27ME3
# MEISSNER_BRAIN_HCP_WITH_H3K27ME3            MEISSNER_BRAIN_HCP_WITH_H3K27ME3
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP       ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3  MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
# MIKKELSEN_MEF_ICP_WITH_H3K27ME3             MIKKELSEN_MEF_ICP_WITH_H3K27ME3
# MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3 MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3
#                                             GeneRatio BgRatio   pvalue
# LU_EZH2_TARGETS_DN                          9/162     399/22381 0.002567407
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN       4/162     222/22381 0.078098118
# KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3     2/162     97/22381  0.155928677
# LU_EZH2_TARGETS_UP                          4/162     289/22381 0.158071142
# PASINI_SUZ12_TARGETS_DN                     4/162     316/22381 0.196503139
# PASINI_SUZ12_TARGETS_UP                     2/162     115/22381 0.202512084
# MIKKELSEN_MCV6_HCP_WITH_H3K27ME3            5/162     438/22381 0.212117663
# KONDO_EZH2_TARGETS                          3/162     229/22381 0.230815843
# MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3  4/162     351/22381 0.249978771
# KAMMINGA_EZH2_TARGETS                       1/162     41/22381  0.257784984
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3  2/162     136/22381 0.258455408
# MEISSNER_NPC_HCP_WITH_H3K27ME3              1/162     79/22381  0.437244445
# MIKKELSEN_NPC_HCP_WITH_H3K27ME3             3/162     346/22381 0.458791973
# MEISSNER_BRAIN_HCP_WITH_H3K27ME3            2/162     272/22381 0.588076333
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP       2/162     290/22381 0.623019072
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3  1/162     143/22381 0.647308080
# MIKKELSEN_MEF_ICP_WITH_H3K27ME3             1/162     207/22381 0.779258369
# MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3 1/162     210/22381 0.784061441
#                                             p.adjust   qvalue
# LU_EZH2_TARGETS_DN                          0.02633938 0.01909731
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN       0.20469780 0.14841568
# KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3     0.27234602 0.19746386
# LU_EZH2_TARGETS_UP                          0.27461445 0.19910858
# PASINI_SUZ12_TARGETS_DN                     0.30477232 0.22097448
# PASINI_SUZ12_TARGETS_UP                     0.30927661 0.22424031
# MIKKELSEN_MCV6_HCP_WITH_H3K27ME3            0.31620757 0.22926558
# KONDO_EZH2_TARGETS                          0.33290954 0.24137530
# MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3  0.35160569 0.25493090
# KAMMINGA_EZH2_TARGETS                       0.35696862 0.25881929
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3  0.35773658 0.25937609
# MEISSNER_NPC_HCP_WITH_H3K27ME3              0.49567212 0.35938594
# MIKKELSEN_NPC_HCP_WITH_H3K27ME3             0.51350113 0.37231282
# MEISSNER_BRAIN_HCP_WITH_H3K27ME3            0.62148519 0.45060642
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP       0.65039990 0.47157096
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3  0.67279951 0.48781175
# MIKKELSEN_MEF_ICP_WITH_H3K27ME3             0.78922592 0.57222646
# MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3 0.79383008 0.57556469
#                                             geneID
# LU_EZH2_TARGETS_DN                          LAMC2/SRPX/CCN2/IL17RD/EGFR/ALPP/MAGED1/BACE2/PHACTR4
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN       CD44/PHGDH/NOMO3/NOMO1
# KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3     XYLT1/FAM171A1
# LU_EZH2_TARGETS_UP                          GANAB/PHGDH/PCK2/APOBEC3F
# PASINI_SUZ12_TARGETS_DN                     SCD/BHLHE40/APP/MYADM
# PASINI_SUZ12_TARGETS_UP                     PCK2/CYP2S1
# MIKKELSEN_MCV6_HCP_WITH_H3K27ME3            NPTX2/TGFBI/SYNDIG1L/COL13A1/NPTXR
# KONDO_EZH2_TARGETS                          CCN2/APP/EGFR
# MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3  TGFB1/SYNDIG1L/COL13A1/NPTXR
# KAMMINGA_EZH2_TARGETS                       MKI67
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3  CD44/SEZ6L2
# MEISSNER_NPC_HCP_WITH_H3K27ME3              CYP2S1
# MIKKELSEN_NPC_HCP_WITH_H3K27ME3             CYP2S1/COL13A1/NPTXR
# MEISSNER_BRAIN_HCP_WITH_H3K27ME3            CDCP1/COL13A1
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP       QSOX1/MAGED1
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3  PDE4A
# MIKKELSEN_MEF_ICP_WITH_H3K27ME3             SEZ6L2
# MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3 TGFB1
#                                             Count
# LU_EZH2_TARGETS_DN                          9
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_DN       4
# KONDO_PROSTATE_CANCER_HCP_WITH_H3K27ME3     2
# LU_EZH2_TARGETS_UP                          4
# PASINI_SUZ12_TARGETS_DN                     4
# PASINI_SUZ12_TARGETS_UP                     2
# MIKKELSEN_MCV6_HCP_WITH_H3K27ME3            5
# KONDO_EZH2_TARGETS                          3
# MEISSNER_NPC_HCP_WITH_H3K4ME2_AND_H3K27ME3  4
# KAMMINGA_EZH2_TARGETS                       1
# MIKKELSEN_ES_ICP_WITH_H3K4ME3_AND_H3K27ME3  2
# MEISSNER_NPC_HCP_WITH_H3K27ME3              1
# MIKKELSEN_NPC_HCP_WITH_H3K27ME3             3
# MEISSNER_BRAIN_HCP_WITH_H3K27ME3            2
# ACEVEDO_LIVER_CANCER_WITH_H3K27ME3_UP       2
# MEISSNER_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3  1
# MIKKELSEN_MEF_ICP_WITH_H3K27ME3             1
# MIKKELSEN_NPC_HCP_WITH_H3K4ME3_AND_H3K27ME3 1

# %%
library(clusterProfiler)

# Subset the result data.frame
prc2_df <- subset(enrich_res@result, grepl("PRC2|POLYCOMB|H3K27|EZH2|SUZ12", Description, ignore.case=TRUE))

# If prc2_df is not empty, create a new enrichResult
if (nrow(prc2_df) > 0) {
  # Copy enrich_res and replace @result with prc2_df
  prc2_res <- enrich_res
  prc2_res@result <- prc2_df
  prc2_res@pvalueCutoff <- 0.5
  prc2_res@qvalueCutoff <- 0.5
  dotplot(prc2_res, showCategory=50)
}
# Out:
# plot without title

# %%
# like this i could do with gsea too maybe?
